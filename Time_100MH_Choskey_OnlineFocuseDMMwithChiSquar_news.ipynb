# %%
from sklearn.datasets import fetch_20newsgroups
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from collections import defaultdict
import gensim
import numpy as np
import pandas as pd
from sklearn.mixture import GaussianMixture
     
def pre_processData(newsgroups_train):
    tokenizer = RegexpTokenizer(r'\w+')
    for i in range(len(newsgroups_train)):
        newsgroups_train[i] = newsgroups_train[i].lower()
        newsgroups_train[i] = tokenizer.tokenize(newsgroups_train[i])
    newsgroups_train = [[token for token in doc if not token.isdigit()] for doc in newsgroups_train]
    #newsgroups_train = [[token for token in doc if len(token) > 3] for doc in newsgroups_train]
    lemmatizer = WordNetLemmatizer()
    newsgroups_train = [[lemmatizer.lemmatize(token) for token in doc] for doc in newsgroups_train]
    return newsgroups_train


def remove_stopwords(documents,news_labels):
    temp_corpus = {}
    temp_label = {}
    stop_en = stopwords.words('english')
    i = 0
    for index, words in enumerate(documents):
        rwords=[]
        for word in words:
            if word not in stop_en:
                rwords.append(word)
        if rwords:
            temp_corpus[i] = rwords
            temp_label[i] = news_labels[index]
            i = i+1
    return temp_corpus,temp_label

def process_wordvectors(vocab,vectors,documents,news_labels):
    useable_vocab = 0
    unusable_vocab = 0
    temp_corpus = {}
    temp_labels = {}
    temp_unvecs = {}
    i=0
    for index in range(len(documents)):
        filter_word = []
        words = documents[index]
        temp_unvecs[i] = {}
        for word in words:
            try:
                vectors[word]
                vocab.add(word)
                filter_word.append(word)
                useable_vocab += 1
            except:
                unusable_vocab += 1
                if word in temp_unvecs[i].keys():
                    temp_unvecs[i][word] +=1
                else:
                     temp_unvecs[i][word] = 1
                continue
        if filter_word and len(words)>0 :
            temp_corpus[i] = filter_word
            temp_labels[i] = news_labels[index]
            #print("doc ",i," not vec word len ",temp_unvecs[i])
            i= i+1
    print("There are {0} words that could be convereted to word vectors in your corpus \n" \
          "There are {1} words that could NOT be converted to word vectors".format(useable_vocab, unusable_vocab))
    print("doc num: ",i)
    print("label num: ",i)
    return temp_corpus,temp_labels,temp_unvecs
import json
if __name__ == "__main__":
    wordvec_fileapth = "glove.6B.50d.txt"
    #remove = ('headers', 'footers', 'quotes')
    #fectch_corpus = fetch_20newsgroups(subset='train', remove=remove)
    #newsgroups_train = fectch_corpus.data
    #print("target_names len ",len(fectch_corpus.target_names))
    #print("newsgroups_train size ",len(newsgroups_train))
    #print("newsgroups_train type ",type(newsgroups_train) )
    newsgroups_train = list()
    news_labels = list()
    supwords_train = list()
    file_path="part_news2.txt"
    #file_path="C:/Users/aa6602623/PycharmProjects/GaussianLDA/News.txt"
    with open(file_path) as fp:
        lines = fp.read().split("\n")
        for line in lines:
            if line:
                text = json.loads(line)["textCleaned"].strip()
                label = json.loads(line)["clusterNo"]
                newsgroups_train.append(text)
                news_labels.append(label)
    fp.close()
    corpus = pre_processData(newsgroups_train)
    corpus,news_labels = remove_stopwords(corpus,news_labels)
    vectors = gensim.models.KeyedVectors.load_word2vec_format(fname=wordvec_fileapth, binary=False)
    vocab = set([])
    corpus,news_labels,supwords_train =  process_wordvectors(vocab,vectors,corpus,news_labels)
    print(len(news_labels))
    print(len(corpus))
# Out:
# There are 68070 words that could be convereted to word vectors in your corpus
# There are 689 words that could NOT be converted to word vectors
# doc num:  11108
# label num:  11108
# 11108
# 11108

# %%
import timeit
from scipy.special import gamma, gammaln, loggamma
from numpy import log, pi, linalg, exp, e
import random
from scipy import stats
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)
import sys
doc_words = {}
for docID in range(len(corpus)):
    doc_words[docID] = {}
    words = corpus[docID]
    for word in words:
        if word not in doc_words[docID].keys():
            doc_words[docID][word] = 0
        doc_words[docID][word] += 1
        
alpha = 0.03
beta = 0.03
docID_assign_z = {}
m_z = {}
n_z = {}
n_w = {}
Topics = []
docID = 0
initial_z = 0
V = set()
D = set()
beta_topic_sum = {}
beta_topic_v = {}
gamma = 0.03
gammaS = 0.0000001

D.add(docID)
docID_assign_z[docID] = initial_z
words = corpus[docID]
if initial_z not in m_z.keys():
    m_z[initial_z] = set()
m_z[initial_z].add(docID)
for word in words:
    if initial_z not in n_w.keys():
        n_w[initial_z] = 0
    if initial_z not in n_z.keys():
        n_z[initial_z] = {}
    if word not in n_z[initial_z].keys():
        n_z[initial_z][word] = 0
    n_z[initial_z][word] += 1
    n_w[initial_z] += 1
    V.add(word)
def sum_topic_word():
    global_important_word = []
    for k in topic_keyword.keys():
        global_important_word.extend(list(topic_keyword[k]))
    x = None
    if len(global_important_word) !=0:
        vec_dim = 0
        for word in global_important_word:
            vec_dim += 1
            if x is not None:
                x = np.row_stack((x, vectors[word]))
            else:
                x = vectors[word] 
        global_v_bar_k[0] = None
        if  vec_dim > 1:
            global_v_bar_k[0]= np.mean(x,axis = 0)[:,None]
        else:
            x = x[:,None]
            global_v_bar_k[0] = x
        x = x.T
        global_kappa_k[0] =  kappa0 + vec_dim
        global_N[0] = vec_dim
        global_C_k[0] = (x - global_v_bar_k[0]).dot((x - global_v_bar_k[0]).T)
        global_mu_k[0] = (kappa0 * mu0 + global_N[0] * global_v_bar_k[0]) / global_kappa_k[0]
        global_psi_k[0] = psi + global_C_k[0] + (kappa0*global_N[0] / global_kappa_k[0])* ( (global_v_bar_k[0] - mu0).T.dot(global_v_bar_k[0] - mu0) )
        global_nu_k[0] = nu0 + vec_dim
        shakage_v = vec_dim + 1
        global_cov_k[0] = global_psi_k[0] / (shakage_v) 
        global_inv_cov_k[0] = np.linalg.inv(global_cov_k[0])
        #global_cov_det_k[0] = np.linalg.det(global_cov_k[0])
    else:
        shakage_v = 20
        global_cov_k[0] = psi/ (shakage_v) 
        global_mu_k[0] = mu0
        global_inv_cov_k[0] = np.linalg.inv(global_cov_k[0])
        #global_cov_det_k[0] = np.linalg.det(global_cov_k[0])
    return global_important_word
def sampleBetaAssignment(k, word,iter,total_iter, max_word_prob):
    if beta_topic_v[k][word] == 1:
        beta_topic_sum[k] -= 1
    pBetaAllOthers = beta_topic_sum[k]
    
    log_true = (n_z[k][word] / n_w[k]) / max_word_prob
    log_false = 1 - log_true
    
    log_p = []
    if log_false <0 or log_true < 0:
        a = 1/0
    log_p.append(log_false)
    log_p.append(log_true)
    
    sum_pro=sum(log_p)
    normalized_posterior = [i/sum_pro for i in log_p]    
    update_k = np.random.choice( 2 , 1, p=normalized_posterior)[0]
    if iter ==  total_iter - 1:
        update_k = 0
        if log_false < log_true:
            update_k = 1
    if update_k == 1:
        beta_topic_v[k][word] = 1
        beta_topic_sum[k] += 1
        topic_keyword[k].add(word)
    else:
        beta_topic_v[k][word] = 0
        topic_keyword[k].discard(word)

# %%
compara_batch = [len(corpus)]

# %%
nmi_compara_batch = []
mean_each_batch_nmi = {}
iteration_nmi = []
iteration_coherence = {}
iteration_topics = {}
iteration_NMI = {}
for i_batch in compara_batch:
    start = 0
    end = 0
    total_batch = None
    if len(corpus) % i_batch == 0:
        total_batch = int(len(corpus) / i_batch)
    else:
        total_batch = int(len(corpus) / i_batch) +1
    mean_each_batch_nmi[i_batch] = []
    for batch in range(total_batch):
        ave_nmi = []
        for mean_i in range(1):
        
            docID_assign_z = {}
            m_z = {}
            n_z = {}
            n_w = {}
            Topics = []
            V = set()
            D = set()
            beta_topic_v = {}
            beta_topic_sum = {}
            topic_keyword = {}
            
            global_v_bar_k = {}
            global_C_k= {}
            global_mu_k= {}
            global_psi_k= {}
            global_nu_k= {}
            global_kappa_k= {}
            global_cov_k= {}
            global_N= {}
            global_inv_cov_k= {}
            global_cov_det_k= {}
            kappa0 = 0.01
            dim = 50
            vec_x = 1.0
            nu0 = dim
            psi = np.eye(dim)
            mu0 = np.array([vec_x for i in range(dim)])[:,None]
            
            alpha = 0.03
            #alpha = 0.003
            
            gamma = 30
            gammaS = 0.03
            #gamma = 0.03
            #gammaS = 0.0000001
            global_word = {}
            global_important_word = None
            
            end = i_batch * (batch + 1)
            if end > len(corpus):
                end = len(corpus)
            total_iter = 10
            for iter in range(total_iter):
                iteration_coherence[iter] = {}
                iteration_topics[iter] = {}
                iteration_NMI[iter] = {}
                print("iter ",iter, " total K ",len(Topics))
#                 for k in Topics:
#                     k_words = set()
#                     for word in beta_topic_v[k]:
#                         if beta_topic_v[k][word] == 1:
#                             k_words.add(word)
                    #print("k ",k , "beta_topic_sum ",beta_topic_sum[k])
                    #print("k ",k , "n_w ",n_w[k])
                #print()
                for docID in range(start,end):
                    if docID%100 == 0:
                        print("iter ",iter, " doc ",docID)
                        print("total K ",len(Topics))
#                     if docID%5000 == 0:
#                         #print("iter ",iter, " m_z ",m_z)
#                         print("iter ",iter, " total K ",Topics)
#                         print()
                    words = corpus[docID]
                    D.discard(docID)
                    if docID in docID_assign_z.keys():
                        before_k = docID_assign_z[docID]
                        m_z[before_k].discard(docID)
                        for word in words:
                            global_word[word] -= 1
                            n_z[before_k][word] -= 1
                            n_w[before_k] -=1
#                         for word in n_z[before_k].keys():
#                             if n_z[before_k][word] > 0:
#                                 sampleBetaAssignment(before_k,word)
                        k = before_k
                        max_word_prob = n_w[k]
                        if max_word_prob != 0:
                            max_word_prob = max(n_z[k].values()) / max_word_prob

                        for word in n_z[k].keys():
                                if word not in beta_topic_v[k].keys():
                                        beta_topic_v[k][word] = 0
                                if n_z[k][word] > 0: 
                                    sampleBetaAssignment(k,word,iter,total_iter,max_word_prob)
                                else:
                                    if beta_topic_v[k][word] == 1:
                                        beta_topic_sum[k] -= 1
                                        beta_topic_v[k][word] = 0  
                                        topic_keyword[k].discard(word)
                        if docID % 500 == 0:
                            global_important_word = sum_topic_word()
                    else:
                        before_k = -1
                        
                    if len(D) == 0 and len(V) == 0:
                        choose_k = 0
                        D.add(docID)
                        docID_assign_z[docID] = choose_k
                        if choose_k not in beta_topic_v.keys(): 
                            beta_topic_v[choose_k] = {}
                        if choose_k not in beta_topic_sum.keys():
                            beta_topic_sum[choose_k] = 0
                        if choose_k not in m_z.keys():
                            m_z[choose_k] = set()
                        if choose_k not in topic_keyword.keys():
                            topic_keyword[choose_k] = set()
                        m_z[choose_k].add(docID)
                        for word in words:
                            if choose_k not in n_w.keys():
                                n_w[choose_k] = 0
                            if choose_k not in n_z.keys():
                                n_z[choose_k] = {}
                            if word not in n_z[choose_k].keys():
                                n_z[choose_k][word] = 0
                            if word not in beta_topic_v[choose_k].keys():
                                beta_topic_v[choose_k][word] = 0
                            if word not in global_word.keys():
                                global_word[word] = 0
                            global_word[word] += 1
                            n_z[choose_k][word] += 1
                            n_w[choose_k] += 1
                            V.add(word)
                        if choose_k not in Topics:
                            Topics.append(choose_k)
#                         if choose_k == Topics:
#                             Topics += 1  
                    else:
                        log_pro = []
                        
                        must_update_flag = 0
                        update_pro = 1
                        not_update_pro = 1
                        if_update_k = []
                        for word in words:
                            if word in global_important_word:
                                must_update_flag = 1
                                break
                            x = vectors[word][:,None]
                            LLcomp = (x - global_mu_k[0]).T.dot(global_inv_cov_k[0]).dot((x - global_mu_k[0])) 
                            pro = stats.chisqprob(LLcomp, dim)[0][0]
                            update_pro *= pro
                            not_update_pro *= (1 - pro)
                            
                        if must_update_flag == 0:
                            if_update_k.append(not_update_pro)
                            if_update_k.append(update_pro)
                            sum_pro=sum(if_update_k)
                            normalized_posterior = [i/sum_pro for i in if_update_k]    
                            update_k = np.random.choice( 2 , 1, p=normalized_posterior)[0]
                        else:
                            update_k = 1
                        
                        choose_k = None
                        if update_k == 1:
                            for k in Topics:
                                pro_k = len(m_z[k])
                                if pro_k == 0:
                                    log_pro.append(0)
                                else:
                                    i = 0
                                    for word in words:
                                        if word not in n_z[k].keys():
                                            n_z[k][word] = 0
                                        bias_flag = 0
                                        if word in beta_topic_v[k].keys():
                                            bias_flag = beta_topic_v[k][word]
                                        for j in range(doc_words[docID][word]):
                                            #pro_k *= (n_z[k][word]+ beta + j) / (n_w[k] + len(V)*beta + i) 
                                            pro_k *= (n_z[k][word]+ bias_flag*gamma + gammaS +j)/(n_w[k]+beta_topic_sum[k]*gamma+len(V)*gammaS +i) 
                                            i += 1
                                    log_pro.append(pro_k)
                            sum_pro=sum(log_pro)
                            normalized_posterior = [i/sum_pro for i in log_pro]  
                            select_k = None
                            if iter == (total_iter - 1):
                                select_k = normalized_posterior.index(max(normalized_posterior))

                            else:
                                select_k = np.random.choice( len(Topics) , 1, p=normalized_posterior)[0]   
                            choose_k = Topics[select_k]
                        else:
                            choose_k = np.max(Topics) + 1
                       
                            
                        D.add(docID)
                        docID_assign_z[docID] = choose_k
                        if choose_k not in m_z.keys():
                            m_z[choose_k] = set()
                        m_z[choose_k].add(docID)
                        if choose_k not in beta_topic_v.keys(): 
                            beta_topic_v[choose_k] = {}
                        if choose_k not in beta_topic_sum.keys():
                            beta_topic_sum[choose_k] = 0
                        if choose_k not in topic_keyword.keys():
                            topic_keyword[choose_k] = set()
                        for word in words:
                            if choose_k not in n_w.keys():
                                n_w[choose_k] = 0
                            if choose_k not in n_z.keys():
                                n_z[choose_k] = {}
                            if word not in n_z[choose_k].keys():
                                n_z[choose_k][word] = 0
                            if word not in beta_topic_v[choose_k].keys():
                                beta_topic_v[choose_k][word] = 0
                            if word not in global_word.keys():
                                global_word[word] = 0
                            global_word[word] += 1
                            n_z[choose_k][word] += 1
                            n_w[choose_k] += 1
                            V.add(word)
                        if choose_k not in Topics:
                            Topics.append(choose_k)
                            
                    count_k = []
                    for k in Topics:
                        if k in m_z.keys() and len(m_z[k]) == 0:
                            m_z.pop(k, None)
                            n_z.pop(k, None)
                            n_w.pop(k, None)
                            beta_topic_v.pop(k, None)
                            beta_topic_sum.pop(k, None)
                            beta_topic_v.pop(k, None)
                            topic_keyword.pop(k, None)
                            count_k.append(k)
                    for k in count_k:
                        Topics.remove(k)   
                        
                    k = choose_k
                    max_word_prob = n_w[k]
                    if max_word_prob != 0:
                        max_word_prob = max(n_z[k].values()) / max_word_prob

                    for word in n_z[k].keys():
                            if word not in beta_topic_v[k].keys():
                                    beta_topic_v[k][word] = 0
                            if n_z[k][word] > 0: 
                                sampleBetaAssignment(k,word,iter,total_iter,max_word_prob)
                            else:
                                if beta_topic_v[k][word] == 1:
                                    beta_topic_sum[k] -= 1
                                    beta_topic_v[k][word] = 0   
                                    topic_keyword[k].discard(word)
                    if docID % 100 == 0:
                        global_important_word = sum_topic_word()                
#                 for k in Topics:
#                     max_word_prob = n_w[k]
#                     if max_word_prob != 0:
#                         max_word_prob = max(n_z[k].values()) / max_word_prob

#                     for word in n_z[k].keys():
#                             if word not in beta_topic_v[k].keys():
#                                     beta_topic_v[k][word] = 0
#                             if n_z[k][word] > 0: 
#                                 sampleBetaAssignment(k,word,iter,total_iter,max_word_prob)
#                             else:
#                                 if beta_topic_v[k][word] == 1:
#                                     beta_topic_sum[k] -= 1
#                                     beta_topic_v[k][word] = 0
                #spiltDocInTopic()
#                 for k in Topics:
#                     flag = 0
#                     print("k ", k)
#                     for word in beta_topic_v[k].keys():
#                         if beta_topic_v[k][word] == 1:
#                             flag = 1
#                             print("import word:",word)
#                     print()
                
                from sklearn.metrics.cluster import normalized_mutual_info_score
                nmi_sample = []
                nmi_result = []
                for key, value in news_labels.items():
                    if key < end and key >= start:
                        nmi_sample.append(value)
                        nmi_result.append(docID_assign_z[key])
                print("iter ",iter," ",normalized_mutual_info_score(np.array(nmi_sample), np.array(nmi_result)))
                iteration_nmi.append(normalized_mutual_info_score(np.array(nmi_sample), np.array(nmi_result)))
                
                threshold_loop = [0, 3, 5, 10, 15, 20]
                for threshold in threshold_loop:
                    count = 0
                    k_count = set()
                    for k in m_z.keys():
                        if len(m_z[k]) >= threshold:
                            count += 1
                            k_count.add(k)
                    import operator
                    post_topic_word = {}
                    for k in k_count:
                        post_topic_word[k] = {}
                        for word in V:
                            pro = None
                            if word in beta_topic_v[k] and beta_topic_v[k][word] == 1:
                                pro = (n_z[k][word]+ beta_topic_v[k][word]*gamma + gammaS) / (n_w[k] + beta_topic_sum[k]*gamma + len(V)*beta) 
                            elif word in n_z[k]:
                                pro = (n_z[k][word]+ gammaS) / (n_w[k] + beta_topic_sum[k]*gamma + len(V)*beta) 
                            else:
                                pro = (gammaS) / (n_w[k] + beta_topic_sum[k]*gamma + len(V)*beta) 
                            post_topic_word[k][word] = pro
                        post_topic_word[k] = sorted(post_topic_word[k].items(), key=operator.itemgetter(1), reverse=True)
                    top = 10
                    topic_coherence = []
                    for k in k_count:
                        top_words = []
                        pro = 0
                        for i in range(top):
                            top_words.append( post_topic_word[k][i][0] )

                        for i in range(len(top_words)-1):
                            for j in range(i+1,len(top_words) ):
                                count_i = 0
                                count_ij = 0
                                for docID in range( len(corpus) ):
                                    if top_words[i] in corpus[docID]:
                                        count_i += 1
                                        if top_words[j] in corpus[docID]:
                                            count_ij += 1
                                pro += log( (count_ij + 1) / count_i )
                        topic_coherence.append(pro)
                    iteration_coherence[iter][threshold] = np.mean(topic_coherence)
                    iteration_topics[iter][threshold] = count
                    
                    nmi_sample = []
                    nmi_result = []
                    for k in k_count:
                        for docID in m_z[k]:
                            nmi_sample.append(news_labels[docID])
                            nmi_result.append(docID_assign_z[docID])
                    iteration_NMI[iter][threshold] = normalized_mutual_info_score(np.array(nmi_sample), np.array(nmi_result))
                    
                print("iter coherence: ",iteration_coherence)
                print("iter topics: ",iteration_topics)
                print("iter NMI: ",iteration_NMI)
                
                
            from sklearn.metrics.cluster import normalized_mutual_info_score
            nmi_sample = []
            nmi_result = []
            for key, value in news_labels.items():
                if key < end and key >= start:
                    nmi_sample.append(value)
                    nmi_result.append(docID_assign_z[key])
            ave_nmi.append(normalized_mutual_info_score(np.array(nmi_sample), np.array(nmi_result)))
        mean_each_batch_nmi[i_batch].append(np.mean(ave_nmi))
        start = end 
        if batch%10 == 0:
            print("i_batch",i_batch , "batch ",batch)
            print(" ave_nmi ",np.mean(ave_nmi))
            print(" mean_each_batch_nmi ",np.mean(mean_each_batch_nmi[i_batch]) ,"max ", np.max(ave_nmi) ,"min ", np.min(ave_nmi) )
            print("total K ",len(Topics))
            print("global_important_word ",len(global_important_word))
            print("iteration_nmi ",iteration_nmi)
            print("iteration_coherence ",iteration_coherence)
            print()
    nmi_compara_batch.append(np.mean(mean_each_batch_nmi[i_batch]))
    print(compara_batch)
    print(nmi_compara_batch)
# Out:
# iter  0  total K  0
# iter  0  doc  0
# total K  0
# iter  0  doc  100
# total K  99
# iter  0  doc  200
# total K  112
# iter  0  doc  300
# total K  119
# iter  0  doc  400
# total K  123
# iter  0  doc  500
# total K  125
# iter  0  doc  600
# total K  126
# iter  0  doc  700
# total K  133
# iter  0  doc  800
# total K  134
# iter  0  doc  900
# total K  137
# iter  0  doc  1000
# total K  138
# iter  0  doc  1100
# total K  141
# iter  0  doc  1200
# total K  141
# iter  0  doc  1300
# total K  142
# iter  0  doc  1400
# total K  144
# iter  0  doc  1500
# total K  145
# iter  0  doc  1600
# total K  146
# iter  0  doc  1700
# total K  146
# iter  0  doc  1800
# total K  147
# iter  0  doc  1900
# total K  148
# iter  0  doc  2000
# total K  149
# iter  0  doc  2100
# total K  153
# iter  0  doc  2200
# total K  153
# iter  0  doc  2300
# total K  153
# iter  0  doc  2400
# total K  154
# iter  0  doc  2500
# total K  158
# iter  0  doc  2600
# total K  161
# iter  0  doc  2700
# total K  163
# iter  0  doc  2800
# total K  164
# iter  0  doc  2900
# total K  166
# iter  0  doc  3000
# total K  166
# iter  0  doc  3100
# total K  168
# iter  0  doc  3200
# total K  170
# iter  0  doc  3300
# total K  170
# iter  0  doc  3400
# total K  170
# iter  0  doc  3500
# total K  171
# iter  0  doc  3600
# total K  172
# iter  0  doc  3700
# total K  172
# iter  0  doc  3800
# total K  173
# iter  0  doc  3900
# total K  174
# iter  0  doc  4000
# total K  174
# iter  0  doc  4100
# total K  175
# iter  0  doc  4200
# total K  175
# iter  0  doc  4300
# total K  175
# iter  0  doc  4400
# total K  176
# iter  0  doc  4500
# total K  177
# iter  0  doc  4600
# total K  179
# iter  0  doc  4700
# total K  180
# iter  0  doc  4800
# total K  180
# iter  0  doc  4900
# total K  183
# iter  0  doc  5000
# total K  183
# iter  0  doc  5100
# total K  184
# iter  0  doc  5200
# total K  184
# iter  0  doc  5300
# total K  186
# iter  0  doc  5400
# total K  188
# iter  0  doc  5500
# total K  189
# iter  0  doc  5600
# total K  190
# iter  0  doc  5700
# total K  191
# iter  0  doc  5800
# total K  191
# iter  0  doc  5900
# total K  191
# iter  0  doc  6000
# total K  192
# iter  0  doc  6100
# total K  192
# iter  0  doc  6200
# total K  194
# iter  0  doc  6300
# total K  195
# iter  0  doc  6400
# total K  195
# iter  0  doc  6500
# total K  196
# iter  0  doc  6600
# total K  197
# iter  0  doc  6700
# total K  197
# iter  0  doc  6800
# total K  198
# iter  0  doc  6900
# total K  200
# iter  0  doc  7000
# total K  201
# iter  0  doc  7100
# total K  201
# iter  0  doc  7200
# total K  202
# iter  0  doc  7300
# total K  203
# iter  0  doc  7400
# total K  204
# iter  0  doc  7500
# total K  204
# iter  0  doc  7600
# total K  206
# iter  0  doc  7700
# total K  206
# iter  0  doc  7800
# total K  207
# iter  0  doc  7900
# total K  209
# iter  0  doc  8000
# total K  211
# iter  0  doc  8100
# total K  211
# iter  0  doc  8200
# total K  211
# iter  0  doc  8300
# total K  211
# iter  0  doc  8400
# total K  213
# iter  0  doc  8500
# total K  213
# iter  0  doc  8600
# total K  213
# iter  0  doc  8700
# total K  214
# iter  0  doc  8800
# total K  214
# iter  0  doc  8900
# total K  214
# iter  0  doc  9000
# total K  216
# iter  0  doc  9100
# total K  216
# iter  0  doc  9200
# total K  217
# iter  0  doc  9300
# total K  217
# iter  0  doc  9400
# total K  217
# iter  0  doc  9500
# total K  217
# iter  0  doc  9600
# total K  217
# iter  0  doc  9700
# total K  217
# iter  0  doc  9800
# total K  219
# iter  0  doc  9900
# total K  219
# iter  0  doc  10000
# total K  219
# iter  0  doc  10100
# total K  220
# iter  0  doc  10200
# total K  220
# iter  0  doc  10300
# total K  222
# iter  0  doc  10400
# total K  222
# iter  0  doc  10500
# total K  223
# iter  0  doc  10600
# total K  225
# iter  0  doc  10700
# total K  225
# iter  0  doc  10800
# total K  225
# iter  0  doc  10900
# total K  225
# iter  0  doc  11000
# total K  225
# iter  0  doc  11100
# total K  225
# iter  0   0.8125584171202477
# iter coherence:  {0: {0: -99.45237469627924, 3: -107.90463077573729, 5: -111.26447618648217, 10: -112.58037311288443, 15: -112.34069598570198, 20: -114.10974785146573}}
# iter topics:  {0: {0: 225, 3: 168, 5: 148, 10: 131, 15: 118, 20: 103}}
# iter NMI:  {0: {0: 0.8125584171202477, 3: 0.8148034628357134, 5: 0.8165181954253463, 10: 0.8191999913497805, 15: 0.8226114336012484, 20: 0.8243976657665808}}
# iter  1  total K  225
# iter  1  doc  0
# total K  225
# iter  1  doc  100
# total K  225
# iter  1  doc  200
# total K  227
# iter  1  doc  300
# total K  227
# iter  1  doc  400
# total K  228
# iter  1  doc  500
# total K  228
# iter  1  doc  600
# total K  228
# iter  1  doc  700
# total K  228
# iter  1  doc  800
# total K  228
# iter  1  doc  900
# total K  229
# iter  1  doc  1000
# total K  229
# iter  1  doc  1100
# total K  229
# iter  1  doc  1200
# total K  229
# iter  1  doc  1300
# total K  231
# iter  1  doc  1400
# total K  231
# iter  1  doc  1500
# total K  230
# iter  1  doc  1600
# total K  230
# iter  1  doc  1700
# total K  230
# iter  1  doc  1800
# total K  230
# iter  1  doc  1900
# total K  230
# iter  1  doc  2000
# total K  230
# iter  1  doc  2100
# total K  230
# iter  1  doc  2200
# total K  230
# iter  1  doc  2300
# total K  230
# iter  1  doc  2400
# total K  229
# iter  1  doc  2500
# total K  231
# iter  1  doc  2600
# total K  231
# iter  1  doc  2700
# total K  232
# iter  1  doc  2800
# total K  232
# iter  1  doc  2900
# total K  233
# iter  1  doc  3000
# total K  234
# iter  1  doc  3100
# total K  234
# iter  1  doc  3200
# total K  233
# iter  1  doc  3300
# total K  235
# iter  1  doc  3400
# total K  235
# iter  1  doc  3500
# total K  234
# iter  1  doc  3600
# total K  235
# iter  1  doc  3700
# total K  236
# iter  1  doc  3800
# total K  235
# iter  1  doc  3900
# total K  235
# iter  1  doc  4000
# total K  235
# iter  1  doc  4100
# total K  235
# iter  1  doc  4200
# total K  235
# iter  1  doc  4300
# total K  235
# iter  1  doc  4400
# total K  236
# iter  1  doc  4500
# total K  236
# iter  1  doc  4600
# total K  235
# iter  1  doc  4700
# total K  235
# iter  1  doc  4800
# total K  234
# iter  1  doc  4900
# total K  233
# iter  1  doc  5000
# total K  233
# iter  1  doc  5100
# total K  233
# iter  1  doc  5200
# total K  234
# iter  1  doc  5300
# total K  234
# iter  1  doc  5400
# total K  232
# iter  1  doc  5500
# total K  232
# iter  1  doc  5600
# total K  231
# iter  1  doc  5700
# total K  230
# iter  1  doc  5800
# total K  230
# iter  1  doc  5900
# total K  231
# iter  1  doc  6000
# total K  231
# iter  1  doc  6100
# total K  232
# iter  1  doc  6200
# total K  230
# iter  1  doc  6300
# total K  230
# iter  1  doc  6400
# total K  230
# iter  1  doc  6500
# total K  230
# iter  1  doc  6600
# total K  230
# iter  1  doc  6700
# total K  229
# iter  1  doc  6800
# total K  228
# iter  1  doc  6900
# total K  227
# iter  1  doc  7000
# total K  227
# iter  1  doc  7100
# total K  228
# iter  1  doc  7200
# total K  229
# iter  1  doc  7300
# total K  229
# iter  1  doc  7400
# total K  228
# iter  1  doc  7500
# total K  229
# iter  1  doc  7600
# total K  228
# iter  1  doc  7700
# total K  229
# iter  1  doc  7800
# total K  229
# iter  1  doc  7900
# total K  229
# iter  1  doc  8000
# total K  229
# iter  1  doc  8100
# total K  230
# iter  1  doc  8200
# total K  230
# iter  1  doc  8300
# total K  230
# iter  1  doc  8400
# total K  230
# iter  1  doc  8500
# total K  229
# iter  1  doc  8600
# total K  229
# iter  1  doc  8700
# total K  228
# iter  1  doc  8800
# total K  230
# iter  1  doc  8900
# total K  230
# iter  1  doc  9000
# total K  229
# iter  1  doc  9100
# total K  229
# iter  1  doc  9200
# total K  229
# iter  1  doc  9300
# total K  230
# iter  1  doc  9400
# total K  230
# iter  1  doc  9500
# total K  230
# iter  1  doc  9600
# total K  230
# iter  1  doc  9700
# total K  230
# iter  1  doc  9800
# total K  229
# iter  1  doc  9900
# total K  229
# iter  1  doc  10000
# total K  228
# iter  1  doc  10100
# total K  228
# iter  1  doc  10200
# total K  228
# iter  1  doc  10300
# total K  226
# iter  1  doc  10400
# total K  227
# iter  1  doc  10500
# total K  226
# iter  1  doc  10600
# total K  225
# iter  1  doc  10700
# total K  225
# iter  1  doc  10800
# total K  225
# iter  1  doc  10900
# total K  226
# iter  1  doc  11000
# total K  226
# iter  1  doc  11100
# total K  226
# iter  1   0.8479007667617451
# iter coherence:  {0: {0: -99.45237469627924, 3: -107.90463077573729, 5: -111.26447618648217, 10: -112.58037311288443, 15: -112.34069598570198, 20: -114.10974785146573}, 1: {0: -97.7502529291291, 3: -104.07349520000194, 5: -106.37165157450859, 10: -109.3457475201979, 15: -109.15124738157455, 20: -112.59101343808385}}
# iter topics:  {0: {0: 225, 3: 168, 5: 148, 10: 131, 15: 118, 20: 103}, 1: {0: 226, 3: 164, 5: 148, 10: 125, 15: 117, 20: 103}}
# iter NMI:  {0: {0: 0.8125584171202477, 3: 0.8148034628357134, 5: 0.8165181954253463, 10: 0.8191999913497805, 15: 0.8226114336012484, 20: 0.8243976657665808}, 1: {0: 0.8479007667617451, 3: 0.8505402520776346, 5: 0.8526436640649349, 10: 0.8557461021011425, 15: 0.8576747162044046, 20: 0.85807092035765}}
# iter  2  total K  226
# iter  2  doc  0
# total K  226
# iter  2  doc  100
# total K  227
# iter  2  doc  200
# total K  226
# iter  2  doc  300
# total K  225
# iter  2  doc  400
# total K  224
# iter  2  doc  500
# total K  224
# iter  2  doc  600
# total K  224
# iter  2  doc  700
# total K  223
# iter  2  doc  800
# total K  224
# iter  2  doc  900
# total K  224
# iter  2  doc  1000
# total K  224
# iter  2  doc  1100
# total K  223
# iter  2  doc  1200
# total K  223
# iter  2  doc  1300
# total K  223
# iter  2  doc  1400
# total K  223
# iter  2  doc  1500
# total K  224
# iter  2  doc  1600
# total K  225
# iter  2  doc  1700
# total K  225
# iter  2  doc  1800
# total K  224
# iter  2  doc  1900
# total K  224
# iter  2  doc  2000
# total K  224
# iter  2  doc  2100
# total K  225
# iter  2  doc  2200
# total K  226
# iter  2  doc  2300
# total K  225
# iter  2  doc  2400
# total K  224
# iter  2  doc  2500
# total K  223
# iter  2  doc  2600
# total K  223
# iter  2  doc  2700
# total K  224
# iter  2  doc  2800
# total K  224
# iter  2  doc  2900
# total K  223
# iter  2  doc  3000
# total K  222
# iter  2  doc  3100
# total K  223
# iter  2  doc  3200
# total K  224
# iter  2  doc  3300
# total K  222
# iter  2  doc  3400
# total K  222
# iter  2  doc  3500
# total K  222
# iter  2  doc  3600
# total K  221
# iter  2  doc  3700
# total K  221
# iter  2  doc  3800
# total K  221
# iter  2  doc  3900
# total K  221
# iter  2  doc  4000
# total K  220
# iter  2  doc  4100
# total K  221
# iter  2  doc  4200
# total K  221
# iter  2  doc  4300
# total K  221
# iter  2  doc  4400
# total K  220
# iter  2  doc  4500
# total K  220
# iter  2  doc  4600
# total K  219
# iter  2  doc  4700
# total K  218
# iter  2  doc  4800
# total K  218
# iter  2  doc  4900
# total K  217
# iter  2  doc  5000
# total K  217
# iter  2  doc  5100
# total K  218
# iter  2  doc  5200
# total K  216
# iter  2  doc  5300
# total K  216
# iter  2  doc  5400
# total K  218
# iter  2  doc  5500
# total K  217
# iter  2  doc  5600
# total K  217
# iter  2  doc  5700
# total K  219
# iter  2  doc  5800
# total K  219
# iter  2  doc  5900
# total K  218
# iter  2  doc  6000
# total K  220
# iter  2  doc  6100
# total K  220
# iter  2  doc  6200
# total K  221
# iter  2  doc  6300
# total K  222
# iter  2  doc  6400
# total K  222
# iter  2  doc  6500
# total K  223
# iter  2  doc  6600
# total K  223
# iter  2  doc  6700
# total K  223
# iter  2  doc  6800
# total K  223
# iter  2  doc  6900
# total K  222
# iter  2  doc  7000
# total K  222
# iter  2  doc  7100
# total K  222
# iter  2  doc  7200
# total K  222
# iter  2  doc  7300
# total K  223
# iter  2  doc  7400
# total K  223
# iter  2  doc  7500
# total K  222
# iter  2  doc  7600
# total K  223
# iter  2  doc  7700
# total K  223
# iter  2  doc  7800
# total K  224
# iter  2  doc  7900
# total K  224
# iter  2  doc  8000
# total K  224
# iter  2  doc  8100
# total K  223
# iter  2  doc  8200
# total K  224
# iter  2  doc  8300
# total K  223
# iter  2  doc  8400
# total K  222
# iter  2  doc  8500
# total K  222
# iter  2  doc  8600
# total K  222
# iter  2  doc  8700
# total K  222
# iter  2  doc  8800
# total K  221
# iter  2  doc  8900
# total K  221
# iter  2  doc  9000
# total K  222
# iter  2  doc  9100
# total K  222
# iter  2  doc  9200
# total K  222
# iter  2  doc  9300
# total K  221
# iter  2  doc  9400
# total K  221
# iter  2  doc  9500
# total K  221
# iter  2  doc  9600
# total K  219
# iter  2  doc  9700
# total K  219
# iter  2  doc  9800
# total K  220
# iter  2  doc  9900
# total K  220
# iter  2  doc  10000
# total K  220
# iter  2  doc  10100
# total K  220
# iter  2  doc  10200
# total K  222
# iter  2  doc  10300
# total K  222
# iter  2  doc  10400
# total K  224
# iter  2  doc  10500
# total K  224
# iter  2  doc  10600
# total K  225
# iter  2  doc  10700
# total K  225
# iter  2  doc  10800
# total K  225
# iter  2  doc  10900
# total K  224
# iter  2  doc  11000
# total K  224
# iter  2  doc  11100
# total K  224
# iter  2   0.8613654145080349
# iter coherence:  {0: {0: -99.45237469627924, 3: -107.90463077573729, 5: -111.26447618648217, 10: -112.58037311288443, 15: -112.34069598570198, 20: -114.10974785146573}, 1: {0: -97.7502529291291, 3: -104.07349520000194, 5: -106.37165157450859, 10: -109.3457475201979, 15: -109.15124738157455, 20: -112.59101343808385}, 2: {0: -94.22221744563457, 3: -102.54322992435141, 5: -105.42764344628385, 10: -108.17886723345612, 15: -107.74326108597603, 20: -109.92813235805652}}
# iter topics:  {0: {0: 225, 3: 168, 5: 148, 10: 131, 15: 118, 20: 103}, 1: {0: 226, 3: 164, 5: 148, 10: 125, 15: 117, 20: 103}, 2: {0: 224, 3: 163, 5: 145, 10: 127, 15: 119, 20: 103}}
# iter NMI:  {0: {0: 0.8125584171202477, 3: 0.8148034628357134, 5: 0.8165181954253463, 10: 0.8191999913497805, 15: 0.8226114336012484, 20: 0.8243976657665808}, 1: {0: 0.8479007667617451, 3: 0.8505402520776346, 5: 0.8526436640649349, 10: 0.8557461021011425, 15: 0.8576747162044046, 20: 0.85807092035765}, 2: {0: 0.8613654145080349, 3: 0.8641319800220816, 5: 0.8660822542648481, 10: 0.8680332097825915, 15: 0.8711386795264949, 20: 0.8726734307263888}}
# iter  3  total K  224
# iter  3  doc  0
# total K  224
# iter  3  doc  100
# total K  223
# iter  3  doc  200
# total K  223
# iter  3  doc  300
# total K  223
# iter  3  doc  400
# total K  223
# iter  3  doc  500
# total K  223
# iter  3  doc  600
# total K  223
# iter  3  doc  700
# total K  222
# iter  3  doc  800
# total K  222
# iter  3  doc  900
# total K  223
# iter  3  doc  1000
# total K  223
# iter  3  doc  1100
# total K  224
# iter  3  doc  1200
# total K  224
# iter  3  doc  1300
# total K  225
# iter  3  doc  1400
# total K  225
# iter  3  doc  1500
# total K  224
# iter  3  doc  1600
# total K  224
# iter  3  doc  1700
# total K  224
# iter  3  doc  1800
# total K  224
# iter  3  doc  1900
# total K  224
# iter  3  doc  2000
# total K  225
# iter  3  doc  2100
# total K  226
# iter  3  doc  2200
# total K  225
# iter  3  doc  2300
# total K  225
# iter  3  doc  2400
# total K  225
# iter  3  doc  2500
# total K  226
# iter  3  doc  2600
# total K  226
# iter  3  doc  2700
# total K  225
# iter  3  doc  2800
# total K  225
# iter  3  doc  2900
# total K  226
# iter  3  doc  3000
# total K  227
# iter  3  doc  3100
# total K  227
# iter  3  doc  3200
# total K  225
# iter  3  doc  3300
# total K  225
# iter  3  doc  3400
# total K  225
# iter  3  doc  3500
# total K  225
# iter  3  doc  3600
# total K  225
# iter  3  doc  3700
# total K  225
# iter  3  doc  3800
# total K  225
# iter  3  doc  3900
# total K  226
# iter  3  doc  4000
# total K  227
# iter  3  doc  4100
# total K  227
# iter  3  doc  4200
# total K  227
# iter  3  doc  4300
# total K  228
# iter  3  doc  4400
# total K  228
# iter  3  doc  4500
# total K  228
# iter  3  doc  4600
# total K  229
# iter  3  doc  4700
# total K  231
# iter  3  doc  4800
# total K  231
# iter  3  doc  4900
# total K  233
# iter  3  doc  5000
# total K  233
# iter  3  doc  5100
# total K  234
# iter  3  doc  5200
# total K  234
# iter  3  doc  5300
# total K  234
# iter  3  doc  5400
# total K  233
# iter  3  doc  5500
# total K  234
# iter  3  doc  5600
# total K  234
# iter  3  doc  5700
# total K  233
# iter  3  doc  5800
# total K  233
# iter  3  doc  5900
# total K  234
# iter  3  doc  6000
# total K  231
# iter  3  doc  6100
# total K  230
# iter  3  doc  6200
# total K  230
# iter  3  doc  6300
# total K  230
# iter  3  doc  6400
# total K  230
# iter  3  doc  6500
# total K  230
# iter  3  doc  6600
# total K  229
# iter  3  doc  6700
# total K  229
# iter  3  doc  6800
# total K  229
# iter  3  doc  6900
# total K  229
# iter  3  doc  7000
# total K  229
# iter  3  doc  7100
# total K  229
# iter  3  doc  7200
# total K  228
# iter  3  doc  7300
# total K  227
# iter  3  doc  7400
# total K  228
# iter  3  doc  7500
# total K  229
# iter  3  doc  7600
# total K  228
# iter  3  doc  7700
# total K  228
# iter  3  doc  7800
# total K  229
# iter  3  doc  7900
# total K  228
# iter  3  doc  8000
# total K  227
# iter  3  doc  8100
# total K  226
# iter  3  doc  8200
# total K  225
# iter  3  doc  8300
# total K  225
# iter  3  doc  8400
# total K  226
# iter  3  doc  8500
# total K  227
# iter  3  doc  8600
# total K  227
# iter  3  doc  8700
# total K  229
# iter  3  doc  8800
# total K  230
# iter  3  doc  8900
# total K  230
# iter  3  doc  9000
# total K  230
# iter  3  doc  9100
# total K  230
# iter  3  doc  9200
# total K  230
# iter  3  doc  9300
# total K  230
# iter  3  doc  9400
# total K  230
# iter  3  doc  9500
# total K  229
# iter  3  doc  9600
# total K  229
# iter  3  doc  9700
# total K  229
# iter  3  doc  9800
# total K  229
# iter  3  doc  9900
# total K  230
# iter  3  doc  10000
# total K  230
# iter  3  doc  10100
# total K  231
# iter  3  doc  10200
# total K  230
# iter  3  doc  10300
# total K  229
# iter  3  doc  10400
# total K  227
# iter  3  doc  10500
# total K  227
# iter  3  doc  10600
# total K  228
# iter  3  doc  10700
# total K  228
# iter  3  doc  10800
# total K  228
# iter  3  doc  10900
# total K  228
# iter  3  doc  11000
# total K  228
# iter  3  doc  11100
# total K  228
# iter  3   0.8627709703224935
# iter coherence:  {0: {0: -99.45237469627924, 3: -107.90463077573729, 5: -111.26447618648217, 10: -112.58037311288443, 15: -112.34069598570198, 20: -114.10974785146573}, 1: {0: -97.7502529291291, 3: -104.07349520000194, 5: -106.37165157450859, 10: -109.3457475201979, 15: -109.15124738157455, 20: -112.59101343808385}, 2: {0: -94.22221744563457, 3: -102.54322992435141, 5: -105.42764344628385, 10: -108.17886723345612, 15: -107.74326108597603, 20: -109.92813235805652}, 3: {0: -97.07362945585966, 3: -102.89574159609782, 5: -107.26440217788756, 10: -109.08071114843221, 15: -108.83985288496274, 20: -110.52253263906151}}
# iter topics:  {0: {0: 225, 3: 168, 5: 148, 10: 131, 15: 118, 20: 103}, 1: {0: 226, 3: 164, 5: 148, 10: 125, 15: 117, 20: 103}, 2: {0: 224, 3: 163, 5: 145, 10: 127, 15: 119, 20: 103}, 3: {0: 228, 3: 172, 5: 147, 10: 122, 15: 115, 20: 106}}
# iter NMI:  {0: {0: 0.8125584171202477, 3: 0.8148034628357134, 5: 0.8165181954253463, 10: 0.8191999913497805, 15: 0.8226114336012484, 20: 0.8243976657665808}, 1: {0: 0.8479007667617451, 3: 0.8505402520776346, 5: 0.8526436640649349, 10: 0.8557461021011425, 15: 0.8576747162044046, 20: 0.85807092035765}, 2: {0: 0.8613654145080349, 3: 0.8641319800220816, 5: 0.8660822542648481, 10: 0.8680332097825915, 15: 0.8711386795264949, 20: 0.8726734307263888}, 3: {0: 0.8627709703224935, 3: 0.8654409650199464, 5: 0.8677774772263518, 10: 0.8716145689149088, 15: 0.8734444858622189, 20: 0.8735486305362725}}
# iter  4  total K  228
# iter  4  doc  0
# total K  228
# iter  4  doc  100
# total K  229
# iter  4  doc  200
# total K  229
# iter  4  doc  300
# total K  229
# iter  4  doc  400
# total K  227
# iter  4  doc  500
# total K  227
# iter  4  doc  600
# total K  227
# iter  4  doc  700
# total K  229
# iter  4  doc  800
# total K  229
# iter  4  doc  900
# total K  229
# iter  4  doc  1000
# total K  228
# iter  4  doc  1100
# total K  228
# iter  4  doc  1200
# total K  228
# iter  4  doc  1300
# total K  227
# iter  4  doc  1400
# total K  228
# iter  4  doc  1500
# total K  229
# iter  4  doc  1600
# total K  229
# iter  4  doc  1700
# total K  229
# iter  4  doc  1800
# total K  230
# iter  4  doc  1900
# total K  230
# iter  4  doc  2000
# total K  229
# iter  4  doc  2100
# total K  227
# iter  4  doc  2200
# total K  227
# iter  4  doc  2300
# total K  227
# iter  4  doc  2400
# total K  225
# iter  4  doc  2500
# total K  225
# total K  235
# iter  5  doc  2700
# total K  234
# iter  5  doc  2800
# total K  234
# iter  5  doc  2900
# total K  235
# iter  5  doc  3000
# total K  235
# iter  5  doc  3100
# total K  234
# iter  5  doc  3200
# total K  233
# iter  5  doc  3300
# total K  234
# iter  5  doc  3400
# total K  234
# iter  5  doc  3500
# total K  233
# iter  5  doc  3600
# total K  231
# iter  5  doc  3700
# total K  231
# iter  5  doc  3800
# total K  231
# iter  5  doc  3900
# total K  231
# iter  5  doc  4000
# total K  231
# iter  5  doc  4100
# total K  231
# iter  5  doc  4200
# total K  231
# iter  5  doc  4300
# total K  230
# iter  5  doc  4400
# total K  230
# iter  5  doc  4500
# total K  230
# iter  5  doc  4600
# total K  231
# iter  5  doc  4700
# total K  232
# iter  5  doc  4800
# total K  232
# iter  5  doc  4900
# total K  232
# iter  5  doc  5000
# total K  231
# iter  5  doc  5100
# total K  231
# iter  5  doc  5200
# total K  231
# iter  5  doc  5300
# total K  232
# iter  5  doc  5400
# total K  233
# iter  5  doc  5500
# total K  233
# iter  5  doc  5600
# total K  233
# iter  5  doc  5700
# total K  232
# iter  5  doc  5800
# total K  232
# iter  5  doc  5900
# total K  231
# iter  5  doc  6000
# total K  230
# iter  5  doc  6100
# total K  228
# iter  5  doc  6200
# total K  229
# iter  5  doc  6300
# total K  230
# iter  5  doc  6400
# total K  230
# iter  5  doc  6500
# total K  230
# iter  5  doc  6600
# total K  229
# iter  5  doc  6700
# total K  229
# iter  5  doc  6800
# total K  228
# iter  5  doc  6900
# total K  230
# iter  5  doc  7000
# total K  230
# iter  5  doc  7100
# total K  230
# iter  5  doc  7200
# total K  228
# iter  5  doc  7300
# total K  228
# iter  5  doc  7400
# total K  229
# iter  5  doc  7500
# total K  228
# iter  5  doc  7600
# total K  226
# iter  5  doc  7700
# total K  226
# iter  5  doc  7800
# total K  227
# iter  5  doc  7900
# total K  227
# iter  5  doc  8000
# total K  228
# iter  5  doc  8100
# total K  227
# iter  5  doc  8200
# total K  227
# iter  5  doc  8300
# total K  227
# iter  5  doc  8400
# total K  227
# iter  5  doc  8500
# total K  228
# iter  5  doc  8600
# total K  227
# iter  5  doc  8700
# total K  227
# iter  5  doc  8800
# total K  227
# iter  5  doc  8900
# total K  227
# iter  5  doc  9000
# total K  226
# iter  5  doc  9100
# total K  226
# iter  5  doc  9200
# total K  227
# iter  5  doc  9300
# total K  226
# iter  5  doc  9400
# total K  226
# iter  5  doc  9500
# total K  226
# iter  5  doc  9600
# total K  226
# iter  5  doc  9700
# total K  226
# iter  5  doc  9800
# total K  225
# iter  5  doc  9900
# total K  225
# iter  5  doc  10000
# total K  226
# iter  5  doc  10100
# total K  227
# iter  5  doc  10200
# total K  227
# iter  5  doc  10300
# total K  226
# iter  5  doc  10400
# total K  229
# iter  5  doc  10500
# total K  230
# iter  5  doc  10600
# total K  229
# iter  5  doc  10700
# total K  229
# iter  5  doc  10800
# total K  229
# iter  5  doc  10900
# total K  229
# iter  5  doc  11000
# total K  228
# iter  5  doc  11100
# total K  230
# iter  6  doc  1700
# total K  230
# iter  6  doc  1800
# total K  230
# iter  6  doc  1900
# total K  231
# iter  6  doc  2000
# total K  232
# iter  6  doc  2100
# total K  231
# iter  6  doc  2200
# total K  232
# iter  6  doc  2300
# total K  231
# iter  6  doc  2400
# total K  229
# iter  6  doc  2500
# total K  228
# iter  6  doc  2600
# total K  228
# iter  6  doc  2700
# total K  230
# iter  6  doc  2800
# total K  230
# iter  6  doc  2900
# total K  230
# iter  6  doc  3000
# total K  230
# iter  6  doc  3100
# total K  232
# iter  6  doc  3200
# total K  233
# iter  6  doc  3300
# total K  232
# iter  6  doc  3400
# total K  233
# iter  6  doc  3500
# total K  233
# iter  6  doc  3600
# total K  233
# iter  6  doc  3700
# total K  234
# iter  6  doc  3800
# total K  234
# iter  6  doc  3900
# total K  234
# iter  6  doc  4000
# total K  234
# iter  6  doc  4100
# total K  234
# iter  6  doc  4200
# total K  235
# iter  6  doc  4300
# total K  235
# iter  6  doc  4400
# total K  233
# iter  6  doc  4500
# total K  233
# iter  6  doc  4600
# total K  233
# iter  6  doc  4700
# total K  232
# iter  6  doc  4800
# total K  233
# iter  6  doc  4900
# total K  233
# iter  6  doc  5000
# total K  233
# iter  6  doc  5100
# total K  233
# iter  6  doc  5200
# total K  233
# iter  6  doc  5300
# total K  233
# iter  6  doc  5400
# total K  232
# iter  6  doc  5500
# total K  232
# iter  6  doc  5600
# total K  232
# iter  6  doc  5700
# total K  231
# iter  6  doc  5800
# total K  230
# iter  6  doc  5900
# total K  230
# iter  6  doc  6000
# total K  231
# iter  6  doc  6100
# total K  233
# iter  6  doc  6200
# total K  232
# iter  6  doc  6300
# total K  231
# iter  6  doc  6400
# total K  232
# iter  6  doc  6500
# total K  232
# iter  6  doc  6600
# total K  233
# iter  6  doc  6700
# total K  233
# iter  6  doc  6800
# total K  234
# iter  6  doc  6900
# total K  234
# iter  6  doc  7000
# total K  234
# iter  6  doc  7100
# total K  234
# iter  6  doc  7200
# total K  234
# iter  6  doc  7300
# total K  235
# iter  6  doc  7400
# total K  234
# iter  6  doc  7500
# total K  234
# iter  6  doc  7600
# total K  235
# iter  6  doc  7700
# total K  235
# iter  6  doc  7800
# total K  234
# iter  6  doc  7900
# total K  235
# iter  6  doc  8000
# total K  236
# iter  6  doc  8100
# total K  237
# iter  6  doc  8200
# total K  238
# iter  6  doc  8300
# total K  237
# iter  6  doc  8400
# total K  237
# iter  6  doc  8500
# total K  237
# iter  6  doc  8600
# total K  237
# iter  6  doc  8700
# total K  237
# iter  6  doc  8800
# total K  236
# iter  6  doc  8900
# total K  236
# iter  6  doc  9000
# total K  238
# iter  6  doc  9100
# total K  238
# iter  6  doc  9200
# total K  239
# iter  6  doc  9300
# total K  240
# iter  6  doc  9400
# total K  240
# iter  6  doc  9500
# total K  240
# iter  6  doc  9600
# total K  239
# iter  6  doc  9700
# total K  239
# iter  6  doc  9800
# total K  240
# iter  6  doc  9900
# total K  240
# iter  6  doc  10000
# total K  239
# iter NMI:  {0: {0: 0.8125584171202477, 3: 0.8148034628357134, 5: 0.8165181954253463, 10: 0.8191999913497805, 15: 0.8226114336012484, 20: 0.8243976657665808}, 1: {0: 0.8479007667617451, 3: 0.8505402520776346, 5: 0.8526436640649349, 10: 0.8557461021011425, 15: 0.8576747162044046, 20: 0.85807092035765}, 2: {0: 0.8613654145080349, 3: 0.8641319800220816, 5: 0.8660822542648481, 10: 0.8680332097825915, 15: 0.8711386795264949, 20: 0.8726734307263888}, 3: {0: 0.8627709703224935, 3: 0.8654409650199464, 5: 0.8677774772263518, 10: 0.8716145689149088, 15: 0.8734444858622189, 20: 0.8735486305362725}, 4: {0: 0.865421154180457, 3: 0.8682741711918446, 5: 0.8708038075749557, 10: 0.874286182957015, 15: 0.877071834578105, 20: 0.8775500574357721}, 5: {0: 0.866210207600184, 3: 0.8690471076598553, 5: 0.8712803729837739, 10: 0.8755296476799804, 15: 0.8776725965526211, 20: 0.8771431514414902}, 6: {0: 0.8676426700883346, 3: 0.8706482159631703, 5: 0.8731437883268048, 10: 0.8761266383512043, 15: 0.8785167390469214, 20: 0.8782832323968951}, 7: {0: 0.8680009454495513, 3: 0.8710910557535375, 5: 0.8746607899016455, 10: 0.8769801272642692, 15: 0.8794760310289818, 20: 0.8790724883927262}}
# iter  8  total K  240
# iter  8  doc  0
# total K  240
# iter  8  doc  100
# total K  241
# iter  8  doc  200
# total K  241
# iter  8  doc  300
# total K  241
# iter  8  doc  400
# total K  242
# iter  8  doc  500
# total K  241
# iter  8  doc  600
# total K  240
# iter  8  doc  700
# total K  240
# iter  8  doc  800
# total K  240
# iter  8  doc  900
# total K  240
# iter  8  doc  1000
# total K  240
# iter  8  doc  1100
# total K  239
# iter  8  doc  1200
# total K  239
# iter  8  doc  1300
# total K  239
# iter  8  doc  1400
# total K  238
# iter  8  doc  1500
# total K  239
# iter  8  doc  1600
# total K  238
# iter  8  doc  1700
# total K  238
# iter  8  doc  1800
# total K  238
# iter  8  doc  1900
# total K  238
# iter  8  doc  2000
# total K  239
# iter  8  doc  2100
# total K  237
# iter  8  doc  2200
# total K  237
# iter  8  doc  2300
# total K  236
# iter  8  doc  2400
# total K  237
# iter  8  doc  2500
# total K  235
# iter  8  doc  2600
# total K  234
# iter  8  doc  2700
# total K  235
# iter  8  doc  2800
# total K  236
# iter  8  doc  2900
# total K  235
# iter  8  doc  3000
# total K  234
# iter  8  doc  3100
# total K  234
# iter  8  doc  3200
# total K  234
# iter  8  doc  3300
# total K  234
# iter  8  doc  3400
# total K  233
# iter  8  doc  3500
# total K  233
# iter  8  doc  3600
# total K  234
# iter  8  doc  3700
# total K  235
# iter  8  doc  3800
# total K  235
# iter  8  doc  3900
# total K  235
# iter  8  doc  4000
# total K  235
# iter  8  doc  4100
# total K  236
# iter  8  doc  4200
# total K  236
# iter  8  doc  4300
# total K  236
# iter  8  doc  4400
# total K  235
# iter  8  doc  4500
# total K  235
# iter  8  doc  4600
# total K  236
# iter  8  doc  4700
# total K  235
# iter  8  doc  4800
# total K  235
# iter  8  doc  4900
# total K  235
# iter  8  doc  5000
# total K  236
# iter  8  doc  5100
# total K  236
# iter  8  doc  5200
# total K  236
# iter  8  doc  5300
# total K  233
# iter  8  doc  5400
# total K  231
# iter  8  doc  5500
# total K  231
# iter  8  doc  5600
# total K  232
# iter  8  doc  5700
# total K  231
# iter  8  doc  5800
# total K  231
# iter  8  doc  5900
# total K  230
# iter  8  doc  6000
# total K  229
# iter  8  doc  6100
# total K  228
# iter  8  doc  6200
# total K  228
# iter  8  doc  6300
# total K  226
# iter  8  doc  6400
# total K  226
# iter  8  doc  6500
# total K  225
# iter  8  doc  6600
# total K  225
# iter  8  doc  6700
# total K  225
# iter  8  doc  6800
# total K  223
# iter  8  doc  6900
# total K  224
# iter  8  doc  7000
# total K  224
# iter  8  doc  7100
# total K  224
# iter  8  doc  7200
# total K  222
# iter  8  doc  7300
# total K  222
# iter  8  doc  7400
# total K  222
# iter  8  doc  7500
# total K  222
# iter  8  doc  7600
# total K  221
# iter  8  doc  7700
# total K  221
# iter  8  doc  7800
# total K  221
# iter  8  doc  7900
# total K  221
# iter  8  doc  8000
# total K  222
# iter  8  doc  8100
# total K  222
# iter  8  doc  8200
# total K  223
# iter  8  doc  8300
# total K  223
# iter  8  doc  8400
# total K  224
# iter  8  doc  8500
# total K  223
# iter  8  doc  8600
# total K  222
# iter  8  doc  8700
# total K  221
# iter  8  doc  8800
# total K  221
# iter  8  doc  8900
# total K  221
# iter  8  doc  9000
# total K  223
# iter  8  doc  9100
# total K  223
# iter  8  doc  9200
# total K  223
# iter  8  doc  9300
# total K  223
# iter  8  doc  9400
# total K  222
# iter  8  doc  9500
# total K  222
# iter  8  doc  9600
# total K  223
# iter  8  doc  9700
# total K  223
# iter  8  doc  9800
# total K  224
# iter  8  doc  9900
# total K  224
# iter  8  doc  10000
# total K  224
# iter  8  doc  10100
# total K  225
# iter  8  doc  10200
# total K  225
# iter  8  doc  10300
# total K  225
# iter  8  doc  10400
# total K  225
# iter  8  doc  10500
# total K  226
# iter  8  doc  10600
# total K  225
# iter  8  doc  10700
# total K  225
# iter  8  doc  10800
# total K  224
# iter  8  doc  10900
# total K  224
# iter  8  doc  11000
# total K  224
# iter  8  doc  11100
# total K  224
# iter  8   0.8662347630879922
# iter coherence:  {0: {0: -99.45237469627924, 3: -107.90463077573729, 5: -111.26447618648217, 10: -112.58037311288443, 15: -112.34069598570198, 20: -114.10974785146573}, 1: {0: -97.7502529291291, 3: -104.07349520000194, 5: -106.37165157450859, 10: -109.3457475201979, 15: -109.15124738157455, 20: -112.59101343808385}, 2: {0: -94.22221744563457, 3: -102.54322992435141, 5: -105.42764344628385, 10: -108.17886723345612, 15: -107.74326108597603, 20: -109.92813235805652}, 3: {0: -97.07362945585966, 3: -102.89574159609782, 5: -107.26440217788756, 10: -109.08071114843221, 15: -108.83985288496274, 20: -110.52253263906151}, 4: {0: -94.97479490676203, 3: -101.36360616724036, 5: -106.04216347473952
# total K  227
# iter  9  doc  400
# total K  227
# iter  9  doc  500
# total K  227
# iter  9  doc  600
# total K  227
# iter  9  doc  700
# total K  227
# iter  9  doc  800
# total K  227
# iter  9  doc  900
# total K  228
# iter  9  doc  1000
# total K  228
# iter  9  doc  1100
# total K  229
# iter  9  doc  1200
# total K  230
# iter  9  doc  1300
# total K  232
# iter  9  doc  1400
# total K  234
# iter  9  doc  1500
# total K  233
# iter  9  doc  1600
# total K  233
# iter  9  doc  1700
# total K  233
# iter  9  doc  1800
# total K  233
# iter  9  doc  1900
# total K  233
# iter  9  doc  2000
# total K  232
# iter  9  doc  2100
# total K  235
# iter  9  doc  2200
# total K  237
# iter  9  doc  2300
# total K  236
# iter  9  doc  2400
# total K  235
# iter  9  doc  2500
# total K  236
# iter  9  doc  2600
# total K  236
# iter  9  doc  2700
# total K  235
# iter  9  doc  2800
# total K  234
# iter  9  doc  2900
# total K  236
# iter  9  doc  3000
# total K  237
# iter  9  doc  3100
# total K  237
# iter  9  doc  3200
# total K  239
# iter  9  doc  3300
# total K  240
# iter  9  doc  3400
# total K  241
# iter  9  doc  3500
# total K  241
# iter  9  doc  3600
# total K  240
# iter  9  doc  3700
# total K  238
# iter  9  doc  3800
# total K  238
# iter  9  doc  3900
# total K  238
# iter  9  doc  4000
# total K  238
# iter  9  doc  4100
# total K  240
# iter  9  doc  4200
# total K  239
# iter  9  doc  4300
# total K  239
# iter  9  doc  4400
# total K  240
# iter  9  doc  4500
# total K  240
# iter  9  doc  4600
# total K  239
# iter  9  doc  4700
# total K  240
# iter  9  doc  4800
# total K  241
# iter  9  doc  4900
# total K  243
# iter  9  doc  5000
# total K  243
# iter  9  doc  5100
# total K  243
# iter  9  doc  5200
# total K  243
# iter  9  doc  5300
# total K  244
# iter  9  doc  5400
# total K  247
# iter  9  doc  5500
# total K  248
# iter  9  doc  5600
# total K  248
# iter  9  doc  5700
# total K  249
# iter  9  doc  5800
# total K  249
# iter  9  doc  5900
# total K  249
# iter  9  doc  6000
# total K  249
# iter  9  doc  6100
# total K  249
# iter  9  doc  6200
# total K  251
# iter  9  doc  6300
# total K  252
# iter  9  doc  6400
# total K  253
# iter  9  doc  6500
# total K  254
# iter  9  doc  6600
# total K  256
# iter  9  doc  6700
# total K  256
# iter  9  doc  6800
# total K  258
# iter  9  doc  6900
# total K  258
# iter  9  doc  7000
# total K  258
# iter  9  doc  7100
# total K  259
# iter  9  doc  7200
# total K  260
# iter  9  doc  7300
# total K  261
# iter  9  doc  7400
# total K  262
# iter  9  doc  7500
# total K  261
# iter  9  doc  7600
# total K  261
# iter  9  doc  7700
# total K  263
# iter  9  doc  7800
# total K  264
# iter  9  doc  7900
# total K  263
# iter  9  doc  8000
# total K  264
# iter  9  doc  8100
# total K  266
# iter  9  doc  8200
# total K  265
# iter  9  doc  8300
# total K  265
# iter  9  doc  8400
# total K  266
# iter  9  doc  8500
# total K  266
# iter  9  doc  8600
# total K  267
# iter  9  doc  8700
# total K  267
# iter  9  doc  8800
# total K  267
8906780699791, 10: -107.32379290367668, 15: -106.93536255696618, 20: -110.29462336424264}, 6: {0: -95.5401286795092, 3: -101.26612265173497, 5: -105.38264405615514, 10: -107.1918543506586, 15: -107.4367779441348, 20: -109.17972542367893}, 7: {0: -95.43642638236425, 3: -100.2056024325534, 5: -104.72017415053966, 10: -106.02397792127947, 15: -106.61589526835195, 20: -108.2126302762404}, 8: {0: -95.55224399426722, 3: -100.44664085842149, 5: -106.70760343541635, 10: -107.12894216295034, 15: -107.85253297603047, 20: -110.31092010485132}, 9: {0: -89.83000815612579, 3: -93.9872894345343, 5: -96.59138548267495, 10: -96.87653989609875, 15: -97.06528456164443, 20: -98.92755010552979}}
#
# [11108]
# [0.8784842687857256]

# %%
topic_word = {}
top_n = 10
for topic_num in n_z.keys():
    top_n_word = sorted(n_z[topic_num].keys(), key=lambda i: n_z[topic_num][i], reverse=True)[:top_n]
    topic_word[topic_num] = [i for i in top_n_word]

# %%
for i in topic_word.keys():
    print("Topic",topic_word[i][0],":",topic_word[i])
# Out:
# Topic nigella : ['nigella', 'lawson', 'drug', 'court', 'saatchi', 'charles', 'head', 'claim', 'cocaine', 'assistant']
# Topic winning : ['winning', 'formula', 'york', 'knicks', 'searching', 'mourinho', 'double', 'player', 'jose', 'dribble']
# Topic johansson : ['johansson', 'globe', 'scarlett', 'golden', 'ineligible', 'voice', 'performance', 'award', 'role', 'deemed']
# Topic storm : ['storm', 'travel', 'thanksgiving', 'holiday', 'east', 'winter', 'weather', 'threatens', 'coast', 'rain']
# Topic manning : ['manning', 'brady', 'peyton', 'tom', 'patriot', 'bronco', 'welker', 'wes', 'week', 'nfl']
# Topic book : ['book', 'record', 'sell', 'psalm', 'auction', 'printed', 'expensive', 'fetch', 'bay', 'america']
# Topic xbox : ['xbox', 'p', 'gamers', 'gift', 'guide', 'disappoint', 'box', 'review', 'black', 'big']
# Topic launch : ['launch', 'philippine', 'campaign', 'program', 'nasa', 'commercial', 'crew', 'unicef', 'rihanna', 'help']
# Topic nokia : ['nokia', 'lumia', 'phone', 'window', 'tablet', 'uk', 'launch', 'ipad', 'price', 'december']
# Topic nsa : ['nsa', 'porn', 'habit', 'spied', 'muslim', 'discredit', 'online', 'radical', 'report', 'monitored']
# Topic adam : ['adam', 'gerry', 'daughter', 'liam', 'jailed', 'year', 'brother', 'raping', 'sentenced', 'ira']
# Topic love : ['love', 'hewitt', 'jennifer', 'baby', 'girl', 'birth', 'welcome', 'brian', 'secretly', 'married']
# Topic seahawks : ['seahawks', 'winfield', 'antoine', 'tate', 'selfish', 'golden', 'call', 'teammate', 'browner', 'carroll']
# Topic nativity : ['nativity', 'black', 'review', 'palestinian', 'hudson', 'israeli', 'holiday', 'movie', 'jennifer', 'whitaker']
# Topic airspace : ['airspace', 'announcement', 'china', 'summons', 'house', 'white', 'update', 'australia', 'chinese', 'ambassador']
# Topic sandy : ['sandy', 'hook', 'report', 'shooting', 'motive', 'school', 'newtown', 'lanza', 'adam', 'massacre']
# Topic net : ['net', 'cowboy', 'raider', 'raptor', 'brooklyn', 'piston', 'dallas', 'game', 'kidd', 'oakland']
# Topic alec : ['alec', 'baldwin', 'msnbc', 'returning', 'air', 'martin', 'bashir', 'cancellation', 'attack', 'time']
# Topic facebook : ['facebook', 'mom', 'hot', 'banned', 'maria', 'kang', 'fit', 'woman', 'obesity', 'comment']
# Topic typhoon : ['typhoon', 'philippine', 'relief', 'aid', 'haiyan', 'effort', 'victim', 'help', 'military', 'farmer']
# Topic seahawks : ['seahawks', 'year', 'suspension', 'thurmond', 'browner', 'girl', 'walter', 'brandon', 'report', 'game']
# Topic comet : ['comet', 'ison', 'sun', 'pope', 'thanksgiving', 'putin', 'nasa', 'encounter', 'century', 'day']
# Topic lakers : ['lakers', 'wizard', 'wall', 'washington', 'john', 'los', 'angeles', 'nba', 'live', 'preview']
# Topic star : ['star', 'duck', 'dallas', 'anaheim', 'nhl', 'goal', 'score', 'third', 'second', 'live']
# Topic hewlett : ['hewlett', 'packard', 'hp', 'earnings', 'company', 'beat', 'estimate', 'sale', 'share', 'stock']
# Topic climate : ['climate', 'refugee', 'change', 'bid', 'zealand', 'man', 'appeal', 'kiribati', 'islander', 'court']
# Topic parade : ['parade', 'macy', 'thanksgiving', 'day', 'balloon', 'wind', 'march', 'ground', 'high', 'perform']
# Topic buffett : ['buffett', 'detroit', 'warren', 'small', 'business', 'huge', 'potential', 'investment', 'walsh', 'dish']
# Topic space : ['space', 'thanksgiving', 'astronaut', 'station', 'student', 'live', 'dinner', 'nasa', 'talk', 'turkey']
# Topic prince : ['prince', 'william', 'taylor', 'swift', 'bon', 'jovi', 'jon', 'prayer', 'gala', 'sings']
# Topic black : ['black', 'friday', 'deal', 'cyber', 'monday', 'best', 'sale', 'shopping', 'shopper', 'buy']
# Topic moto : ['moto', 'motorola', 'early', 'smartphone', 'unlocked', 'order', 'cheap', 'launch', 'start', 'shipping']
# Topic chelsea : ['chelsea', 'basel', 'mourinho', 'champion', 'league', 'jose', 'despite', 'loss', 'fc', 'preview']
# Topic coalition : ['coalition', 'german', 'merkel', 'deal', 'spd', 'germany', 'party', 'social', 'reach', 'democrat']
# Topic packer : ['packer', 'game', 'eddie', 'lacy', 'asthma', 'viking', 'left', 'banged', 'kickoff', 'falcon']
# Topic central : ['central', 'african', 'republic', 'france', 'troop', 'send', 'car', 'force', 'chaos', 'boost']
# Topic star : ['star', 'dancing', 'riley', 'amber', 'season', 'finale', 'microsoft', 'win', 'winner', 'bill']
# Topic army : ['army', 'chief', 'sharif', 'pakistan', 'raheel', 'gen', 'lt', 'general', 'appointed', 'pm']
# Topic meningitis : ['meningitis', 'princeton', 'vaccine', 'cdc', 'university', 'outbreak', 'student', 'case', 'expert', 'college']
# Topic flu : ['flu', 'death', 'swine', 'higher', 'time', 'toll', 'pandemic', 'cancer', 'risk', 'thought']
# Topic irs : ['irs', 'tax', 'political', 'exempt', 'group', 'rule', 'proposes', 'nonprofit', 'obama', 'activity']
# Topic xbox : ['xbox', 'microsoft', 'game', 'console', 'p', 'free', 'drive', 'launch', 'disc', 'sale']
# Topic price : ['price', 'rise', 'september', 'shiller', 'housing', 'case', 'gain', 'sp', 'year', 'pace']
# Topic china : ['china', 'zone', 'air', 'japan', 'defense', 'thai', 'protester', 'bomber', 'disputed', 'sea']
# Topic nurse : ['nurse', 'stabbing', 'texas', 'hospital', 'stabbed', 'killed', 'patient', 'protecting', 'good', 'center']
# Topic berlusconi : ['berlusconi', 'vote', 'senate', 'italy', 'government', 'italian', 'confidence', 'expulsion', 'silvio', 'parliament']
# Topic flacco : ['flacco', 'joe', 'wildcat', 'raven', 'offense', 'high', 'school', 'rip', 'formation', 'tyrod']
# Topic alzheimer : ['alzheimer', 'risk', 'brain', 'hiv', 'infant', 'progression', 'genetic', 'difference', 'gene', 'supplement']
# Topic hp : ['hp', 'sale', 'hope', 'enterprise', 'turnaround', 'stir', 'pickup', 'update', 'hewlett', 'packard']
# Topic immigration : ['immigration', 'reform', 'activist', 'fast', 'hunger', 'thanksgiving', 'obama', 'join', 'boehner', 'strike']
# Topic men : ['men', 'bank', 'wearhouse', 'jos', 'bid', 'buy', 'offer', 'turn', 'table', 'icahn']
# Topic keith : ['keith', 'urban', 'hair', 'chop', 'computer', 'common', 'sense', 'signature', 'cut', 'long']
# Topic rogen : ['rogen', 'franco', 'kanye', 'bound', 'seth', 'james', 'west', 'video', 'kim', 'parody']
# Topic kobe : ['kobe', 'bryant', 'lakers', 'extension', 'contract', 'year', 'deal', 'sign', 'gasol', 'nba']
# Topic burger : ['burger', 'king', 'france', 'mcdonald', 'worldwide', 'expand', 'take', 'joint', 'venture', 'form']
# Topic regret : ['regret', 'men', 'woman', 'stadium', 'sexual', 'cup', 'collapse', 'sex', 'study', 'three']
# Topic oldboy : ['oldboy', 'lee', 'spike', 'review', 'remake', 'homefront', 'josh', 'brolin', 'movie', 'film']
# Topic patriot : ['patriot', 'bronco', 'belichick', 'ot', 'bill', 'win', 'brady', 'overtime', 'lead', 'wind']
# Topic concussion : ['concussion', 'welker', 'wes', 'player', 'nhl', 'bronco', 'patriot', 'lawsuit', 'return', 'injury']
# Topic frozen : ['frozen', 'disney', 'review', 'movie', 'princess', 'bell', 'kristen', 'heart', 'ice', 'tale']
# Topic packer : ['packer', 'viking', 'rodgers', 'lion', 'flynn', 'detroit', 'aaron', 'green', 'matt', 'bay']
# Topic manning : ['manning', 'peyton', 'cold', 'continue', 'struggle', 'division', 'leader', 'focus', 'hype', 'mother']
# Topic thanksgiving : ['thanksgiving', 'black', 'hanukkah', 'shopping', 'friday', 'holiday', 'day', 'store', 'retailer', 'rare']
# Topic fire : ['fire', 'ant', 'raft', 'form', 'healing', 'survive', 'flood', 'material', 'inspire', 'video']
# Topic irs : ['irs', 'hardware', 'case', 'employee', 'paying', 'maintain', 'retired', 'ig', 'baby', 'access']
# Topic window : ['window', 'phone', 'latin', 'america', 'outsells', 'io', 'mobile', 'remains', 'second', 'platform']
# Topic independence : ['independence', 'scotland', 'scottish', 'paper', 'white', 'salmond', 'independent', 'blueprint', 'alex', 'snp']
# Topic weatherford : ['weatherford', 'pay', 'settle', 'international', 'fine', 'violation', 'charge', 'guilty', 'firm', 'plead']
# Topic woman : ['woman', 'pill', 'morning', 'attack', 'work', 'pound', 'pain', 'iraq', 'heart', 'kill']
# Topic sriracha : ['sriracha', 'judge', 'factory', 'hot', 'sauce', 'order', 'plant', 'cool', 'smelly', 'odor']
# Topic cameron : ['cameron', 'migrant', 'benefit', 'david', 'cancer', 'eu', 'migration', 'bid', 'bulgarian', 'attack']
# Topic kanye : ['kanye', 'west', 'kim', 'kardashian', 'adidas', 'nike', 'yeezus', 'deal', 'woman', 'north']
# Topic lecavalier : ['lecavalier', 'tampa', 'flyer', 'xbox', 'return', 'bay', 'tv', 'lightning', 'uk', 'excited']
# Topic illinois : ['illinois', 'northern', 'lynch', 'michigan', 'western', 'niu', 'jordan', 'husky', 'record', 'bcs']
# Topic chemical : ['chemical', 'evacuated', 'ohio', 'hundred', 'leak', 'willard', 'spill', 'force', 'evacuation', 'train']
# Topic andreas : ['andreas', 'san', 'grand', 'theft', 'auto', 'mobile', 'coming', 'gta', 'december', 'android']
# Topic watkins : ['watkins', 'ian', 'lostprophets', 'singer', 'guilty', 'pleads', 'sex', 'child', 'baby', 'rape']
# Topic berlusconi : ['berlusconi', 'career', 'silvio', 'political', 'date', 'best', 'open', 'defense', 'high', 'movie']
# Topic risk : ['risk', 'salt', 'medicine', 'heart', 'attack', 'stroke', 'high', 'sodium', 'painkiller', 'level']
# Topic qb : ['qb', 'duel', 'materialized', 'litke', 'backup', 'qbs', 'essential', 'government', 'grant', 'reduce']
# Topic sony : ['sony', 'patent', 'file', 'hairpiece', 'tech', 'seek', 'smart', 'wig', 'hair', 'sensor']
# Topic hpv : ['hpv', 'vaccine', 'vaccination', 'cancer', 'barrier', 'teen', 'scare', 'hit', 'france', 'parent']
# Topic bmw : ['bmw', 'sold', 'car', 'year', 'model', 'top', 'energy', 'xbox', 'report', 'family']
# Topic security : ['security', 'karzai', 'afghan', 'troop', 'deal', 'afghanistan', 'pact', 'rice', 'agreement', 'president']
# Topic specie : ['specie', 'endangered', 'list', 'forest', 'bird', 'red', 'threatened', 'bonobo', 'okapi', 'extinction']
# Topic kinect : ['kinect', 'xbox', 'apple', 'microsoft', 'sensor', 'company', 'voice', 'command', 'buy', 'gesture']
# Topic market : ['market', 'ecb', 'financial', 'nov', 'risk', 'improvement', 'see', 'turmoil', 'mover', 'stability']
# Topic curiosity : ['curiosity', 'mar', 'rover', 'electrical', 'glitch', 'resume', 'nasa', 'problem', 'science', 'voltage']
# Topic hanukkah : ['hanukkah', 'maccabees', 'arrived', 'miracle', 'essay', 'listener', 'reinventing', 'documentary', 'screening', 'featured']
# Topic talk : ['talk', 'syria', 'peace', 'geneva', 'syrian', 'january', 'iran', 'set', 'conference', 'opposition']
# Topic methane : ['methane', 'study', 'oxytocin', 'emission', 'hormone', 'monogamy', 'love', 'epa', 'men', 'estimate']
# Topic bbm : ['bbm', 'blackberry', 'channel', 'android', 'device', 'social', 'pre', 'network', 'oems', 'smartphones']
# Topic cheese : ['cheese', 'human', 'scientist', 'bacteria', 'toe', 'microbe', 'jam', 'skin', 'body', 'creates']
# Topic homefront : ['homefront', 'statham', 'review', 'jason', 'movie', 'action', 'stallone', 'franco', 'james', 'video']
# Topic moscow : ['moscow', 'islamist', 'detained', 'police', 'extremist', 'group', 'explosive', 'detain', 'russian', 'militant']
# Topic jellyfish : ['jellyfish', 'robot', 'flying', 'fly', 'tiny', 'air', 'drone', 'machine', 'video', 'move']
# Topic hill : ['hill', 'resigns', 'juan', 'dixon', 'maryland', 'assistant', 'terps', 'coach', 'hire', 'staff']
# Topic susilo : ['susilo', 'bambang', 'yudhoyono', 'indonesian', 'president', 'precise', 'measure', 'lack', 'abbott', 'tony']
# Topic supernova : ['supernova', 'mach', 'shock', 'wave', 'tycho', 'remnant', 'light', 'reverse', 'astronomer', 'shockwave']
# Topic barneys : ['barneys', 'store', 'monitor', 'profiling', 'police', 'amid', 'security', 'claim', 'camera', 'room']
# Topic aid : ['aid', 'anti', 'day', 'track', 'ten', 'key', 'drug', 'thousand', 'patient', 'goal']
# Topic cell : ['cell', 'stem', 'researcher', 'identify', 'cancer', 'thing', 'prostate', 'despite', 'lab', 'tout']
# Topic boston : ['boston', 'park', 'smoking', 'ban', 'daily', 'talker', 'week', 'resident', 'expected', 'public']
# Topic vonn : ['vonn', 'lindsey', 'sochi', 'injury', 'knee', 'crash', 'time', 'ski', 'chance', 'olympic']
# Topic dwts : ['dwts', 'karina', 'dance', 'tribute', 'michael', 'iconic', 'corbin', 'jackson', 'practice', 'smirnoff']
# Topic warrant : ['warrant', 'suthep', 'arrest', 'leader', 'protest', 'court', 'thai', 'issued', 'ready', 'top']
# Topic plymouth : ['plymouth', 'rock', 'menorah', 'celebrate', 'tip', 'rabbi', 'moshe', 'bleich', 'lighting', 'planned']
# Topic knicks : ['knicks', 'york', 'woodson', 'mike', 'shumpert', 'carmelo', 'anthony', 'stoudemire', 'amar', 'iman']
# Topic library : ['library', 'congress', 'brody', 'jenner', 'invited', 'kim', 'kardashian', 'wedding', 'microsoft', 'busted']
# Topic polymer : ['polymer', 'gel', 'nanorods', 'regenerate', 'severed', 'large', 'proposes', 'university', 'part', 'heal']
# Topic resigns : ['resigns', 'supermarket', 'collapse', 'pm', 'latvian', 'latvia', 'roof', 'prime', 'minister', 'deadly']
# Topic seahorse : ['seahorse', 'head', 'prey', 'shaped', 'video', 'odd', 'horse', 'stealth', 'catch', 'predator']
# Topic andray : ['andray', 'blatche', 'score', 'joe', 'johnson', 'start', 'watch', 'brooklyn', 'punch', 'hit']
# Topic fda : ['fda', 'test', 'dna', 'genetic', 'testing', 'selling', 'kit', 'halt', 'google', 'tell']
# Topic peter : ['peter', 'ben', 'schiff', 'bound', 'lawson', 'market', 'salmond', 'view', 'saatchi', 'eat']
# Topic mo : ['mo', 'movember', 'money', 'team', 'bring', 'going', 'news', 'lancashire', 'college', 'grows']
# Topic movember : ['movember', 'moustache', 'pm', 'pmqs', 'calling', 'men', 'choosing', 'student', 'prime', 'minister']
# Topic ice : ['ice', 'circle', 'river', 'north', 'dakota', 'form', 'rare', 'unusual', 'spinning', 'sheyenne']
# Topic report : ['report', 'irs', 'leaving', 'ig', 'taxpayer', 'info', 'vulnerable', 'hacker', 'romeo', 'juliet']
# Topic operation : ['operation', 'karachi', 'continue', 'objective', 'sharif', 'pm', 'crime', 'met', 'anti', 'achievement']
# Topic prosecutor : ['prosecutor', 'conn', 'gunman', 'motive', 'unknown', 'abuse', 'vatican', 'problem', 'great', 'abc']
# Topic failure : ['failure', 'pin', 'bug', 'cech', 'football', 'independence', 'white', 'paper', 'promise', 'childcare']
# Topic weight : ['weight', 'loss', 'artery', 'gastric', 'embolization', 'left', 'aid', 'future', 'method', 'surgery']
# Topic winston : ['winston', 'heisman', 'charge', 'decision', 'deadline', 'acc', 'fsu', 'ruling', 'voting', 'game']
# Topic youtube : ['youtube', 'comment', 'spam', 'google', 'system', 'update', 'commenting', 'issue', 'fight', 'fix']
# Topic sign : ['sign', 'shorten', 'pleased', 'indon', 'aust', 'sector', 'strength', 'indonesia', 'liam', 'adam']
# Topic sen : ['sen', 'whitehouse', 'nonprofit', 'campaigning', 'historic', 'book', 'psalm', 'set', 'auction', 'record']
# Topic icahn : ['icahn', 'share', 'buy', 'carl', 'interactive', 'group', 'stock', 'gta', 'publisher', 'stake']
# Topic punch : ['punch', 'gut', 'heartstrings', 'tug', 'homefront', 'review', 'video', 'tugging', 'nawaz', 'sharif']
# Topic gratitude : ['gratitude', 'grateful', 'good', 'thanksgiving', 'health', 'attitude', 'year', 'benefit', 'chance', 'dessert']
# Topic spawning : ['spawning', 'mashup', 'seasonal', 'celebration', 'unconventional', 'preview', 'patriot', 'bronco', 'leading', 'oems']
# Topic white : ['white', 'paper', 'culture', 'football', 'feast', 'nationalist', 'rape', 'barnes', 'coverage', 'view']
# Topic thailand : ['thailand', 'protest', 'political', 'anti', 'bangkok', 'escalate', 'govt', 'spread', 'government', 'crisis']
# Topic lee : ['lee', 'sean', 'expected', 'leadership', 'injured', 'coach', 'dallas', 'weather', 'thursday', 'mlb']
# Topic daily : ['daily', 'jolt', 'grab', 'dish', 'tarpon', 'spring', 'h', 'band', 'perform', 'macy']
# Topic google : ['google', 'view', 'street', 'park', 'canada', 'holiday', 'macy', 'online', 'thing', 'offer']
# Topic israel : ['israel', 'shift', 'julie', 'bishop', 'view', 'australia', 'balance', 'government', 'strong', 'sp']
# Topic drug : ['drug', 'greece', 'open', 'centre', 'consumption', 'addict', 'safe', 'crisis', 'set', 'hit']
# Topic deron : ['deron', 'williams', 'sunday', 'brook', 'lopez', 'ruled', 'ankle', 'xbox', 'model', 'coming']
# Topic putin : ['putin', 'kiss', 'madonna', 'icon', 'vatican', 'pope', 'chat', 'minute', 'oops', 'youtube']
# Topic biggest : ['biggest', 'city', 'democrat', 'party', 'resident', 'cluster', 'nokia', 'reveals', 'lumia', 'successor']
# Topic st : ['st', 'joseph', 'ind', 'husky', 'race', 'illinois', 'fresno', 'bcs', 'niu', 'ohio']
# Topic kim : ['kim', 'wedding', 'brody', 'kardashian', 'jenner', 'kanye', 'invited', 'west', 'invite', 'sell']
# Topic steubenville : ['steubenville', 'rape', 'superintendent', 'coach', 'indicted', 'probe', 'tv', 'ohio', 'rock', 'investigation']
# Topic turtle : ['turtle', 'shipwreck', 'robot', 'underwater', 'help', 'inspect', 'bot', 'explore', 'archaeologist', 'ancient']
# Topic system : ['system', 'stress', 'ecb', 'banking', 'level', 'pre', 'crisis', 'financial', 'decline', 'fallen']
# Topic challenge : ['challenge', 'yellen', 'face', 'analysis', 'early', 'tough', 'expect', 'repeat', 'tenure', 'mon']
# Topic prostate : ['prostate', 'cancer', 'checked', 'player', 'town', 'bit', 'column', 'tackle', 'stand', 'testicular']
# Topic plan : ['plan', 'poll', 'tax', 'voter', 'blasio', 'support', 'pre', 'state', 'hike', 'find']
# Topic conference : ['conference', 'earnings', 'financial', 'hormel', 'food', 'call', 'guidance', 'donation', 'scheduled', 'baptism']
# Topic denver : ['denver', 'mcdaniels', 'mark', 'josh', 'friend', 'left', 'foe', 'send', 'kindle', 'england']
# Topic john : ['john', 'wall', 'jam', 'gif', 'throw', 'find', 'trevor', 'ariza', 'thai', 'protester']
# Topic mourinho : ['mourinho', 'feeling', 'heat', 'football', 'bay', 'psalm', 'book', 'set', 'record', 'auction']
# Topic andrew : ['andrew', 'robb', 'minister', 'tapping', 'govt', 'backtracks', 'confirmation', 'indonesian', 'phone', 'breaking']
# Topic street : ['street', 'wall', 'suit', 'detroit', 'men', 'weigh', 'cheap', 'guy', 'excited', 'diamond']
# Topic obama : ['obama', 'group', 'secretive', 'murder', 'honor', 'letter', 'accountable', 'ideological', 'person', 'overspending']
# Topic chelsea : ['chelsea', 'low', 'reach', 'woe', 'striking', 'stat', 'samuel', 'eto', 'leg', 'muscle']
# Topic detroit : ['detroit', 'duggan', 'service', 'comeback', 'improving', 'optimistic', 'focused', 'mayor', 'elect', 'calendar']
# Topic yeezus : ['yeezus', 'best', 'complex', 'experience', 'staffer', 'recall', 'collective', 'tour', 'triumph', 'filipino']
# Topic dna : ['dna', 'force', 'turn', 'mass', 'pet', 'condo', 'pooper', 'scooper', 'compliance', 'doggie']
# Topic weekly : ['weekly', 'pop', 'forecast', 'google', 'add', 'extension', 'chrome', 'store', 'kim', 'kardashian']
# Topic camera : ['camera', 'speed', 'light', 'nano', 'operates', 'operate', 'mit', 'inexpensive', 'developed', 'work']
# Topic recipe : ['recipe', 'spertus', 'institute', 'unorthodox', 'latke', 'brooklyn', 'net', 'serious', 'long', 'term']
# Topic thankful : ['thankful', 'doc', 'matt', 'flynn', 'full', 'circle', 'packer', 'scott', 'tolzien', 'benched']
# Topic dallas : ['dallas', 'cowboy', 'rookie', 'lb', 'holloman', 'play', 'thursday', 'fourth', 'bill', 'belichick']
# Topic hormone : ['hormone', 'reward', 'monogamy', 'western', 'michigan', 'unable', 'northern', 'illinois', 'heisman', 'hopeful']
# Topic yale : ['yale', 'shiller', 'housing', 'uncharted', 'territory', 'vote', 'loom', 'expel', 'italy', 'berlusconi']
# Topic backup : ['backup', 'qbs', 'essential', 'government', 'grant', 'reduce', 'hiv', 'infection', 'study', 'kim']
# Topic islam : ['islam', 'democracy', 'danger', 'net', 'lose', 'hp', 'quarterly', 'revenue', 'beat', 'share']
# Topic family : ['family', 'forgiveness', 'xbox', 'adolescent', 'falling', 'gap', 'hiv', 'service', 'taylor', 'swift']
# Topic jason : ['jason', 'statham', 'cruising', 'bruising', 'kanye', 'west', 'yeezus', 'follow', 'arrive', 'year']
# Topic anton : ['anton', 'china', 'creates', 'air', 'defence', 'zone', 'east', 'sea', 'official', 'share']
# Topic bit : ['bit', 'nfl', 'playoff', 'barneys', 'monitor', 'nyc', 'store', 'camera', 'room', 'curb']
# Topic cup : ['cup', 'wednesday', 'bid', 'nfl', 'taint', 'grey', 'glory', 'scotland', 'picture', 'rosy']
# Topic appreciation : ['appreciation', 'bench', 'bound', 'spoof', 'kanye', 'west', 'seth', 'rogen', 'james', 'franco']
# Topic killed : ['killed', 'iraq', 'attack', 'ecb', 'marked', 'decline', 'systemic', 'stress', 'banking', 'system']
# Topic winona : ['winona', 'jew', 'celebrate', 'verizon', 'nokia', 'lumia', 'amazon', 'deal', 'online', 'monday']
# Topic modern : ['modern', 'holiday', 'foretold', 'scripture', 'trap', 'honey', 'moto', 'unlocked', 'contract', 'galaxy']
# Topic iran : ['iran', 'underreporting', 'fish', 'catch', 'thanksgiving', 'travel', 'weather', 'forecast', 'region', 'lower']
# Topic glass : ['glass', 'interesting', 'lower', 'manhattan', 'bakery', 'creates', 'donut', 'rock', 'singer', 'admits']
# Topic meaning : ['meaning', 'european', 'share', 'rise', 'german', 'government', 'deal', 'youtube', 'bug', 'comment']
# Topic chinese : ['chinese', 'air', 'defense', 'news', 'pope', 'francis', 'denounces', 'rapacious', 'capitalism', 'south']
# Topic find : ['find', 'twist', 'tail', 'pope', 'francis', 'denounces', 'rapacious', 'capitalism', 'south', 'africa']
# Topic swear : ['swear', 'fact', 'thanksgiving', 'dancing', 'star', 'recap', 'finale', 'winner', 'defective', 'xbox']
# Topic censure : ['censure', 'debate', 'yingluck', 'kick', 'hanukkah', 'sundown', 'thanksgiving', 'fall', 'day', 'hewlett']
# Topic battle : ['battle', 'ballad', 'hanukkah', 'thanksgiving', 'fall', 'day', 'hewlett', 'packard', 'earnings', 'watch']
# Topic thinker : ['thinker', 'strategic', 'interest', 'letter', 'commentary', 'reason', 'buy', 'xbox', 'p', 'christmas']
# Topic weather : ['weather', 'warmer', 'temperature', 'rain', 'recipe', 'spertus', 'institute', 'typhoon', 'survivor', 'tacloban']
# Topic indo : ['indo', 'pak', 'speak', 'loc', 'burroughs', 'pope', 'francis', 'unfairly', 'attacked', 'wichita']
# Topic taper : ['taper', 'dollar', 'trade', 'sideways', 'chart', 'cheese', 'human', 'bacteria', 'thinking', 'eating']
# Topic season : ['season', 'ticket', 'valid', 'test', 'beat', 'hiv', 'brandon', 'browner', 'reportedly', 'suspended']
# Topic soluble : ['soluble', 'painkiller', 'linked', 'major', 'health', 'problem', 'msnbc', 'fire', 'alec', 'baldwin']
# Topic oecd : ['oecd', 'urge', 'massive', 'deregulation', 'greek', 'economy', 'bank', 'chief', 'lend', 'kanye']
# Topic stoudemire : ['stoudemire', 'express', 'frustration', 'nigella', 'lawson', 'accused', 'secret', 'drug', 'habit', 'peter']
# Topic progress : ['progress', 'secured', 'courtesy', 'schalke', 'goalless', 'draw', 'bucharest', 'cameron', 'isolated', 'push']
# Topic web : ['web', 'scientist', 'prototype', 'flying', 'robotic', 'jellyfish', 'flyer', 'roster', 'ready', 'rough']
# Topic holiday : ['holiday', 'calorie', 'meal', 'nsa', 'spied', 'porn', 'surfing', 'discredit', 'reveals', 'snowden']
# Topic treasury : ['treasury', 'department', 'announces', 'settlement', 'melby', 'march', 'macy', 'thanksgiving', 'day', 'parade']
# Topic scientist : ['scientist', 'image', 'learning', 'kristen', 'bell', 'princess', 'frozen', 'scrappy', 'awkward', 'infant']
# Topic golf : ['golf', 'cost', 'comet', 'ison', 'latest', 'nasa', 'thanksgiving', 'video', 'perilous', 'path']
# Topic syrian : ['syrian', 'government', 'opposition', 'agree', 'sit', 'january', 'nokia', 'lumia', 'officially', 'unveiled']
# Topic mitch : ['mitch', 'kupchak', 'address', 'medium', 'nokia', 'lumia', 'officially', 'unveiled', 'saatchi', 'claim']
# Topic javascript : ['javascript', 'mail', 'address', 'claim', 'adam', 'ira', 'irrelevant', 'mcguinness', 'kardashian', 'love']
# Topic samuel : ['samuel', 'eto', 'leg', 'muscle', 'strain', 'motorola', 'moto', 'early', 'entry', 'time']
# Topic notable : ['notable', 'quotable', 'senkaku', 'island', 'dispute', 'comet', 'ison', 'approaching', 'sun', 'seth']
# Topic top : ['top', 'ranked', 'europe', 'etf', 'buy', 'champion', 'league', 'group', 'basel', 'stun']
# Topic shaikh : ['shaikh', 'khalifa', 'reaffirms', 'uae', 'solidarity', 'palestinian', 'cancer', 'vaccine', 'scare', 'spark']
# Topic hiller : ['hiller', 'thriller', 'seth', 'rogen', 'james', 'franco', 'skewer', 'kanye', 'kim', 'music']
# Topic interactive : ['interactive', 'software', 'announces', 'repurchase', 'black', 'friday', 'creep', 'restaurant', 'eye', 'opportunity']
# Topic negotiation : ['negotiation', 'conflict', 'france', 'sending', 'troop', 'central', 'african', 'republic', 'prevent', 'collapse']
# Topic mania : ['mania', 'interview', 'idina', 'menzel', 'wood', 'moto', 'variant', 'debut', 'thanksgiving', 'brandon']
# Topic happened : ['happened', 'talwars', 'convicted', 'pic', 'rape', 'scandal', 'festering', 'steubenville', 'charge', 'best']
# Topic appliance : ['appliance', 'rf', 'ft', 'compact', 'refrigerator', 'alec', 'baldwin', 'msnbc', 'gay', 'slur']
# Topic sprint : ['sprint', 'corp', 'downgraded', 'sector', 'perform', 'pacific', 'crest', 'bill', 'belichick', 'break']
# Topic mortgage : ['mortgage', 'rate', 'rose', 'prospect', 'earlier', 'qe', 'bill', 'belichick', 'break', 'pre']
# Topic obamacare : ['obamacare', 'application', 'defies', 'china', 'flying', 'bomber', 'disputed', 'airspace', 'germany', 'grand']
# Topic thai : ['thai', 'protester', 'force', 'evacuation', 'ministry', 'oust', 'gov', 'top', 'crime', 'agency']
# Topic htc : ['htc', 'gold', 'arrives', 'uk', 'packer', 'josh', 'sitton', 'lion', 'dirtbags', 'market']
# Topic microsoft : ['microsoft', 'con', 'compliment', 'live', 'patriot', 'alfonzo', 'dennard', 'aqib', 'talib', 'mix']
# Topic woody : ['woody', 'shumpert', 'looked', 'totally', 'lost', 'report', 'nsa', 'track', 'online', 'porn']
# Topic grateful : ['grateful', 'record', 'breaking', 'number', 'hiv', 'case', 'recorded', 'gay', 'men', 'highest']
# Topic bishop : ['bishop', 'ready', 'visit', 'jakarta', 'soothe', 'spy', 'row', 'hill', 'resigns', 'terps']
# Topic calendar : ['calendar', 'alignment', 'creates', 'brody', 'jenner', 'invite', 'kim', 'kardashian', 'warning', 'morning']
# Topic male : ['male', 'celebrity', 'magnificent', 'long', 'hair', 'call', 'raven', 'qb', 'offense', 'high']
# Topic nah : ['nah', 'three', 'girl', 'escape', 'year', 'captivity', 'jason', 'statham', 'find', 'sweet']
# Topic banking : ['banking', 'byte', 'iraq', 'economy', 'boost', 'stanchart', 'petrodollars', 'deadly', 'storm', 'system']
# Topic sketch : ['sketch', 'alex', 'salmond', 'pound', 'drum', 'keith', 'urban', 'cut', 'signature', 'long']
# Topic evaluating : ['evaluating', 'characteristic', 'chest', 'pain', 'early', 'diagnosis', 'book', 'psalm', 'worth', 'nsa']
# Topic movie : ['movie', 'stock', 'future', 'ahead', 'data', 'deluge', 'video', 'murat', 'yakin', 'basel']
# Topic dinner : ['dinner', 'refuse', 'talwars', 'inconsolable', 'video', 'murat', 'yakin', 'basel', 'playing', 'chelsea']
# Topic fine : ['fine', 'oilfield', 'company', 'mln', 'usd', 'prince', 'william', 'rock', 'bon', 'jovi']
# Topic tale : ['tale', 'browser', 'chrome', 'chromium', 'study', 'estimate', 'swine', 'flu', 'death', 'toll']
# Topic watch : ['watch', 'wmu', 'gametime', 'tv', 'radio', 'streaming', 'preview', 'affordable', 'moto', 'ship']
# Topic sinn : ['sinn', 'fein', 'head', 'brother', 'jailed', 'abuse', 'nokia', 'lumia', 'south', 'africa']
# Topic smashed : ['smashed', 'hit', 'livin', 'prayer', 'lakers', 'wizard', 'taylor', 'swift', 'amazing', 'multiple']
# Topic stupid : ['stupid', 'storm', 'upset', 'travel', 'macy', 'wait', 'parade', 'call', 'wizard', 'lakers']
# Topic national : ['national', 'football', 'league', 'roundup', 'microsoft', 'admits', 'xbox', 'hardware', 'failure', 'russia']
# Topic russian : ['russian', 'police', 'detain', 'alleged', 'funders', 'banned', 'islamic', 'party', 'fun', 'animated']
